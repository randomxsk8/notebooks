# %%
# %run "../../08222019_functions.ipynb"

# %%
abba_baba('2L', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('2L', 'CIcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('2L', 'GHcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('2L', 'GNcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('2L', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)

# %% [markdown]
# -------------------------------------------------

# %%
abba_baba('3L', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3L', 'CIcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3L', 'GHcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3L', 'GNcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3L', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)

# %% [markdown]
# ---------------------------

# %%
abba_baba('3R', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)
# Out:
# /opt/conda/lib/python3.6/site-packages/allel/stats/admixture.py:430: RuntimeWarning: invalid value encountered in true_divide
#   vb = num_bsum / den_bsum

# %%
abba_baba('3R', 'CIcol', 'BFgam', 'AOcol', 'chri', 10000)
# Out:
# /opt/conda/lib/python3.6/site-packages/allel/stats/admixture.py:430: RuntimeWarning: invalid value encountered in true_divide
#   vb = num_bsum / den_bsum

# %%
abba_baba('3R', 'GHcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3R', 'GNcol', 'BFgam', 'AOcol', 'chri', 10000)

# %%
abba_baba('3R', 'BFcol', 'BFgam', 'AOcol', 'chri', 10000)

# %% [markdown]
# -------------------
