# %%
# %run "../../08222019_functions.ipynb"

# %% [markdown]
# Test the 5 avaiable populations of phase2 (AOcol, BFcol, CIcol, GHcol, GNcol) independently against each <i>An.gambiae</i> population, using the allopatric <i>An.gambiae</i> population from Gabon (GAgam) which is genetically distinct from the others and at the end <i>An.christyi</i> as outgroup:
#
# > (Agam<SUB>Pop</SUB>, GAgam), Acol<SUB>pop</SUB>, Outgroup
#
# <i>An.gambiae</i> populations:
# <list>
# - GHgam
# - CMgam
# - FRgam
# - BFgam
# - GNgam
# - GQgam
# - UGgam
# </list>
#
# <i>An.coluzzii</i> populations:
# <list>
# - AOcol
# - BFcol
# - CIcol
# - GHcol
# - GNcol
# </list>
#
# So there are 35 comparisons for each chromosomal arm
#
#
# <b>Notes:</b>
# > Under incomplete lineage sorting alone, two sister species are expected to share about the same proportion of derived alleles with a third closely related species. Thus, if species "P1" and "P2" are sisters and "P3" is a closely related species, then the number of derived alleles shared by P1 and P3 but not P2 and the number of derived alleles that is shared by P2 and P3 but not P1 should be approximately similar. In contrast, if hybridization leads to introgression between species P3 and one out the two species P1 and P2, then P3 should share more derived alleles with that species than it does with the other one, leading to asymmetry in the sharing of derived alleles. These expectations are the basis for the so-called "ABBA-BABA test" (first described in the Supporting Material of Green et al. 2010) that quantifies support for introgression by the D-statistic. In addition to the three species P1, P2, and P3, the ABBA-BABA test requires a fourth species, "P4", which should be a common outgroup to P1, P2, and P3, and only serves to determine which allele is the ancestral one and which is derived; the ancestral allele is then labelled "A" and the derived allele of a bi-allelic SNP is labelled "B". In the simplest case in which only a single haploid sequence is sampled from each of the four species, "ABBA sites" are those where species P2 and P3 share the derived allele B while P1 retains the ancestral allele A. Similarly "BABA sites" are those where P1 and P3 share the derived allele B while P2 retains the ancestral allele A. The D-statistic is then defined as the difference between the counts of ABBA sites and BABA sites relative to the sum of both types of sites:
# >> D = (CABBA - CBABA) / (CABBA + CBABA)
#
# > This statistic is expected to be 0 if no introgression occurred, to be 1 in the extreme case of no incomplete lineage sorting but introgression between P2 and P3, and -1 if incomplete lineage sorting is absent but introgression occurred between P1 and P3.

# %% [markdown]
# ## Chromosome 3L

# %% [markdown]
# Create allele count new map for <i>An.christyi</i> for phase2

# %% [markdown]
# Performing ABBA-BABA Test with AOcol population for each <i>An.gambiae</i> population:

# %%
calldata_chri= h5py.File('../../chri_ac_phase2_map.h5', mode='r')
calldata_chri.keys()
# Out:
# <KeysViewHDF5 ['2L', '2R', '3L', '3R', 'X']>

# %%
ac_chri = allel.AlleleCountsArray(calldata_chri['3L'])

# %%
abba_baba('3L', 'GHgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.009123071900299217
# Estimated standard error: 0.003236613771093023
# Z-score: -2.8187088560827274

# %%
abba_baba('3L', 'CMgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.014924281370627653
# Estimated standard error: 0.00308803681691023
# Z-score: -4.832935050806911

# %%
abba_baba('3L', 'BFgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.015821582421601095
# Estimated standard error: 0.0030847524257001623
# Z-score: -5.128963442831231

# %%
abba_baba('3L', 'GAgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.011018070333225091
# Estimated standard error: 0.0030814067611196075
# Z-score: 3.575662412456625

# %%
abba_baba('3L', 'GNgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.016349813488935175
# Estimated standard error: 0.0031274087133687056
# Z-score: -5.227910704170125

# %%
abba_baba('3L', 'GQgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.008961426532011083
# Estimated standard error: 0.003329430365280988
# Z-score: 2.6915795042479527

# %%
abba_baba('3L', 'UGgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0133851373850887
# Estimated standard error: 0.0031005353204045585
# Z-score: -4.317040769379852

# %% [markdown]
# Performing ABBA-BABA Test with BFcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3L', 'GHgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.0011561439935544014
# Estimated standard error: 0.0029495233960081784
# Z-score: 0.3919765461494904

# %%
abba_baba('3L', 'CMgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.007706372556893588
# Estimated standard error: 0.002759913927881482
# Z-score: -2.7922510477741684

# %%
abba_baba('3L', 'BFgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.005206987065466961
# Estimated standard error: 0.0026727529625038588
# Z-score: -1.9481737139630775

# %%
abba_baba('3L', 'GAgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.00341441633328403
# Estimated standard error: 0.0028527014937646377
# Z-score: 1.1969062801513493

# %%
abba_baba('3L', 'GNgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.006912714948307433
# Estimated standard error: 0.002754776077163766
# Z-score: -2.5093563885688144

# %%
abba_baba('3L', 'GQgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.006436625299586878
# Estimated standard error: 0.002963348406646731
# Z-score: 2.1720784789090803

# %%
abba_baba('3L', 'UGgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.00874189955426462
# Estimated standard error: 0.0028185503467400754
# Z-score: -3.1015587727128833

# %% [markdown]
# Performing ABBA-BABA Test with CIcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3L', 'GHgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.0035538186089630963
# Estimated standard error: 0.0029367440428272346
# Z-score: 1.2101220117030689

# %%
abba_baba('3L', 'CMgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.006681647335285356
# Estimated standard error: 0.002797957121485348
# Z-score: -2.388044936063308

# %%
abba_baba('3L', 'BFgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.004546624520432526
# Estimated standard error: 0.002705760521548181
# Z-score: -1.6803499364500447

# %%
abba_baba('3L', 'GAgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.005711028136998526
# Estimated standard error: 0.0028531797789329853
# Z-score: 2.001636272332724

# %%
abba_baba('3L', 'GNgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.00591906133804047
# Estimated standard error: 0.002791308250402133
# Z-score: -2.1205330286211614

# %%
abba_baba('3L', 'GQgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.008056763471201595
# Estimated standard error: 0.002987701934426815
# Z-score: 2.696642318420318

# %%
abba_baba('3L', 'UGgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.007780378371261022
# Estimated standard error: 0.002861297153745447
# Z-score: -2.719178733700022

# %% [markdown]
# Performing ABBA-BABA Test with GHcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3L', 'GHgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.003405522816463657
# Estimated standard error: 0.002942771662790256
# Z-score: 1.1572501052407962

# %%
abba_baba('3L', 'CMgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.006827074665594077
# Estimated standard error: 0.0028047546271604815
# Z-score: -2.434107639749496

# %%
abba_baba('3L', 'BFgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.004787315037367597
# Estimated standard error: 0.002703234104939898
# Z-score: -1.7709583600692385

# %%
abba_baba('3L', 'GAgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.006078239882784388
# Estimated standard error: 0.0028687387016731636
# Z-score: 2.1187847743816173

# %%
abba_baba('3L', 'GNgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.006200228928730424
# Estimated standard error: 0.0027909933533138654
# Z-score: -2.2215133265611784

# %%
abba_baba('3L', 'GQgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.008419581618059079
# Estimated standard error: 0.0029960692079125557
# Z-score: 2.81020932220896

# %%
abba_baba('3L', 'UGgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.007948689668332393
# Estimated standard error: 0.0028762691063870115
# Z-score: -2.7635417182215742

# %% [markdown]
# Performing ABBA-BABA Test with GNcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3L', 'GHgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.003614246721667305
# Estimated standard error: 0.003123312357047421
# Z-score: 1.1571838831656216

# %%
abba_baba('3L', 'CMgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.006301405347990474
# Estimated standard error: 0.0028798986629630895
# Z-score: -2.1880649583367777

# %%
abba_baba('3L', 'BFgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.004559017719582646
# Estimated standard error: 0.002807244649359757
# Z-score: -1.6240186692037735

# %%
abba_baba('3L', 'GAgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.005552833954362548
# Estimated standard error: 0.00300540714092501
# Z-score: 1.847614547376595

# %%
abba_baba('3L', 'GNgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.005492533615448447
# Estimated standard error: 0.002899801594401573
# Z-score: -1.8941066954554633

# %%
abba_baba('3L', 'GQgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.007798045507218033
# Estimated standard error: 0.003079134071323909
# Z-score: 2.532544970951906

# %%
abba_baba('3L', 'UGgam', 'FRgam', 'GNcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.007317457248556512
# Estimated standard error: 0.0029001947209346002
# Z-score: -2.52309170682113

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ## Chromosome 3R

# %%
calldata_chri= h5py.File('../../chri_ac_phase2_map.h5', mode='r')
calldata_chri.keys()
# Out:
# <KeysViewHDF5 ['2L', '2R', '3L', '3R', 'X']>

# %%
ac_chri = allel.AlleleCountsArray(calldata_chri['3R'])

# %% [markdown]
# Performing ABBA-BABA Test with AOcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3R', 'GHgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# /opt/conda/lib/python3.6/site-packages/allel/stats/admixture.py:430: RuntimeWarning: invalid value encountered in true_divide
#   vb = num_bsum / den_bsum
# Estimated value of the statistic using all data: -0.013129533422123797
# Estimated standard error: 0.002957216829181644
# Z-score: -4.439827777443414

# %%
abba_baba('3R', 'CMgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.019487779125579866
# Estimated standard error: 0.002970676863277407
# Z-score: -6.560046757855691

# %%
abba_baba('3R', 'BFgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.017716385900152287
# Estimated standard error: 0.00296474354634011
# Z-score: -5.975689169480663

# %%
abba_baba('3R', 'GAgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.007776280836694551
# Estimated standard error: 0.0027672829318760536
# Z-score: 2.810077981951305

# %%
abba_baba('3R', 'GNgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.01864438143129601
# Estimated standard error: 0.003005200072965031
# Z-score: -6.20403999022296

# %%
abba_baba('3R', 'GQgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0006346363301808429
# Estimated standard error: 0.003143797302079825
# Z-score: -0.2018693539055428

# %%
abba_baba('3R', 'UGgam', 'FRgam', 'AOcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.016443726923274102
# Estimated standard error: 0.002894981687046142
# Z-score: -5.680079772819652

# %% [markdown]
# Performing ABBA-BABA Test with BFcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3R', 'GHgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0025392237705585663
# Estimated standard error: 0.0025946190964245635
# Z-score: -0.9786499197734523

# %%
abba_baba('3R', 'CMgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.011480953704062363
# Estimated standard error: 0.002649474607725704
# Z-score: -4.3332944843421455

# %%
abba_baba('3R', 'BFgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.008089037200676425
# Estimated standard error: 0.002620023847701107
# Z-score: -3.087390676910825

# %%
abba_baba('3R', 'GAgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.0028724137372998304
# Estimated standard error: 0.0025527666549257384
# Z-score: 1.1252159423805193

# %%
abba_baba('3R', 'GNgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.008550618442560921
# Estimated standard error: 0.002658089473534921
# Z-score: -3.2168286762708878

# %%
abba_baba('3R', 'GQgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0011175043087426142
# Estimated standard error: 0.002744143210380504
# Z-score: -0.4072325032146047

# %%
abba_baba('3R', 'UGgam', 'FRgam', 'BFcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.010885531395871836
# Estimated standard error: 0.002596626636358636
# Z-score: -4.192181980824589

# %% [markdown]
# Performing ABBA-BABA Test with CIcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3R', 'GHgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0016396824866752348
# Estimated standard error: 0.0025532770616854376
# Z-score: -0.6421874505044384

# %%
abba_baba('3R', 'CMgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.010879407450820219
# Estimated standard error: 0.002634442338498946
# Z-score: -4.129681371966977

# %%
abba_baba('3R', 'BFgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.007593914998618681
# Estimated standard error: 0.0026121045360040134
# Z-score: -2.907201796079655

# %%
abba_baba('3R', 'GAgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: 0.0027024148219243864
# Estimated standard error: 0.002511588334134704
# Z-score: 1.0759784098357925

# %%
abba_baba('3R', 'GNgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.008311735771758842
# Estimated standard error: 0.0026507871919964373
# Z-score: -3.135572631727886

# %%
abba_baba('3R', 'GQgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0005632250131125976
# Estimated standard error: 0.002728406421044106
# Z-score: -0.20643002771451577

# %%
abba_baba('3R', 'UGgam', 'FRgam', 'CIcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.010632383972033872
# Estimated standard error: 0.0025746212678181696
# Z-score: -4.12968855067532

# %% [markdown]
# Performing ABBA-BABA Test with GHcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3R', 'GHgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.0018250569608889778
# Estimated standard error: 0.0025783954778439335
# Z-score: -0.7078266218551931

# %%
abba_baba('3R', 'CMgam', 'FRgam', 'GHcol', ac_chri, 10000)
# Out:
# Estimated value of the statistic using all data: -0.011573814669849398
# Estimated standard error: 0.002662429826406261
# Z-score: -4.347087218997879

# %%
abba_baba('3R', 'BFgam', 'FRgam', 'GHcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GAgam', 'FRgam', 'GHcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GNgam', 'FRgam', 'GHcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GQgam', 'FRgam', 'GHcol', ac_chri, 10000)

# %%
abba_baba('3R', 'UGgam', 'FRgam', 'GHcol', ac_chri, 10000)

# %% [markdown]
# Performing ABBA-BABA Test with GNcol population for each <i>An.gambiae</i> population:

# %%
abba_baba('3R', 'GHgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'CMgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'BFgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GAgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GNgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'GQgam', 'FRgam', 'GNcol', ac_chri, 10000)

# %%
abba_baba('3R', 'UGgam', 'FRgam', 'GNcol', ac_chri, 10000)
