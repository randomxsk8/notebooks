# %% [markdown]
# # Dxy, $\pi$ and Gmin analysis on sympatric populations
#
# Based on chapter X of the paper I reperform the Dxy, $\pi$ and Gmin analysis on sympatric phase2 populations of: Burkina Faso, Ghana and Guinea.
# I used two old Alistair's notebooks:
#
# - <b> 20150528 Haplotype distance scan - compute distance matrices</b> For computing Dxy distances, I compute these distances on windows of 100kbp in the two cromosomal arm 3L and 3R.
# - <b> 20150529 Haplotype distance scan - 2 population plots </b> For plotting Dxy, $\pi$ and Gmin over the chromosome

# %% [markdown]
# ### Import modules for the analysis:

# %%
import os
import allel
import zarr
import pandas as pd
import h5py
import petl as etl
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import h5py
import pyfasta
import bcolz
import glob
import itertools

# %%
#From imports of Alistair
import sys
import gc
import datetime
import humanize
from humanize import naturalsize, intcomma, intword


def log(*msg):
    print(' '.join(map(str, msg)), file=sys.stdout)
    sys.stdout.flush()
    
from contextlib import contextmanager

@contextmanager
def timer(*msg):
    before = datetime.datetime.now()
    try:
        yield
    except:
        after = datetime.datetime.now()
        elapsed = (after - before).total_seconds()
        done = 'errored after %s' % humanize.naturaldelta(elapsed)
        if not msg:
            msg = done
        else:
            msg = ', '.join(map(str, msg)) + ', ' + done
        print(msg, file=sys.stderr)
        sys.stderr.flush()   
        raise
    else:
        after = datetime.datetime.now()
        elapsed = (after - before).total_seconds()
        done = 'done in %s' % humanize.naturaldelta(elapsed)
        if not msg:
            msg = done
        else:
            msg = ', '.join(map(str, msg)) + ', ' + done
        print(msg, file=sys.stdout)
        sys.stdout.flush()

# %% [markdown]
# Import metadata, genome and accessibility:

# %%
tbl_samples = pd.read_csv("D:\Genomes\meta\samples.meta.txt", sep = "\t")
tbl_samples
# Out:
#        ox_code         src_code population        country     location  \
# 0     AA0040-C  Twifo_Praso__E2      GHcol          Ghana  Twifo Praso
# 1     AA0041-C  Twifo_Praso__H3      GHcol          Ghana  Twifo Praso
# 2     AA0042-C      Takoradi_C7      GHcol          Ghana     Takoradi
# 3     AA0043-C      Takoradi_H8      GHcol          Ghana     Takoradi
# 4     AA0044-C     Takoradi_D10      GHcol          Ghana     Takoradi
# 5     AA0048-C        Madina_A1      GHgam          Ghana       Madina
# 6     AA0049-C        Madina_E3      GHcol          Ghana       Madina
# 7     AA0050-C        Madina_E5      GHgam          Ghana       Madina
# 8     AA0051-C  Twifo_Praso__C1      GHcol          Ghana  Twifo Praso
# 9     AA0052-C  Twifo_Praso__F2      GHcol          Ghana  Twifo Praso
# 10    AA0053-C  Twifo_Praso__A4      GHcol          Ghana  Twifo Praso
# 11    AA0054-C      Takoradi_E7      GHcol          Ghana     Takoradi
# 12    AA0055-C      Takoradi_B9      GHcol          Ghana     Takoradi
# 13    AA0056-C     Takoradi_G10      GHcol          Ghana     Takoradi
# 14    AA0060-C        Madina_C1      GHgam          Ghana       Madina
# 15    AA0061-C        Madina_F3      GHgam          Ghana       Madina
# 16    AA0063-C  Twifo_Praso__D1      GHcol          Ghana  Twifo Praso
# 17    AA0064-C  Twifo_Praso__G2      GHcol          Ghana  Twifo Praso
# 18    AA0066-C      Takoradi_G7      GHcol          Ghana     Takoradi
# 19    AA0067-C      Takoradi_C9      GHcol          Ghana     Takoradi
# 20    AA0068-C     Takoradi_H10      GHcol          Ghana     Takoradi
# 21    AA0072-C        Madina_F1      GHgam          Ghana       Madina
# 22    AA0073-C        Madina_H3      GHcol          Ghana       Madina
# 23    AA0074-C        Madina_G5      GHcol          Ghana       Madina
# 24    AA0075-C  Twifo_Praso__F1      GHcol          Ghana  Twifo Praso
# 25    AA0076-C  Twifo_Praso__B3      GHcol          Ghana  Twifo Praso
# 26    AA0077-C  Twifo_Praso__C4      GHcol          Ghana  Twifo Praso
# 27    AA0080-C     Takoradi_A11      GHcol          Ghana     Takoradi
# 28    AA0084-C        Madina_A2      GHgam          Ghana       Madina
# 29    AA0085-C        Madina_A4      GHgam          Ghana       Madina
# ...        ...              ...        ...            ...          ...
# 1112  AY0056-C        Tia_aPM_8      CIcol  Cote d'Ivoire     Tiassale
# 1113  AY0057-C       Tia_aPM_17      CIcol  Cote d'Ivoire     Tiassale
# 1114  AY0058-C       Tia_aPM_25      CIcol  Cote d'Ivoire     Tiassale
# 1115  AY0059-C       Tia_aPM_36      CIcol  Cote d'Ivoire     Tiassale
# 1116  AY0060-C       Tia_aPM_30      CIcol  Cote d'Ivoire     Tiassale
# 1117  AY0061-C        Tia_dPM_3      CIcol  Cote d'Ivoire     Tiassale
# 1118  AY0062-C       Tia_dPM_10      CIcol  Cote d'Ivoire     Tiassale
# 1119  AY0063-C       Tia_dPM_18      CIcol  Cote d'Ivoire     Tiassale
# 1120  AY0064-C       Tia_dPM_25      CIcol  Cote d'Ivoire     Tiassale
# 1121  AY0065-C       Tia_dPM_48      CIcol  Cote d'Ivoire     Tiassale
# 1122  AY0066-C       Tia_dPM_54      CIcol  Cote d'Ivoire     Tiassale
# 1123  AY0067-C        Tia_aPM_6      CIcol  Cote d'Ivoire     Tiassale
# 1124  AY0068-C       Tia_aPM_15      CIcol  Cote d'Ivoire     Tiassale
# 1125  AY0069-C       Tia_aPM_24      CIcol  Cote d'Ivoire     Tiassale
# 1126  AY0070-C       Tia_aPM_35      CIcol  Cote d'Ivoire     Tiassale
# 1127  AY0072-C        Tia_dPM_2      CIcol  Cote d'Ivoire     Tiassale
# 1128  AY0074-C       Tia_dPM_17      CIcol  Cote d'Ivoire     Tiassale
# 1129  AY0076-C       Tia_dPM_47      CIcol  Cote d'Ivoire     Tiassale
# 1130  AY0077-C       Tia_dPM_53      CIcol  Cote d'Ivoire     Tiassale
# 1131  AY0078-C        Tia_aPM_5      CIcol  Cote d'Ivoire     Tiassale
# 1132  AY0079-C       Tia_aPM_14      CIcol  Cote d'Ivoire     Tiassale
# 1133  AY0080-C       Tia_aPM_23      CIcol  Cote d'Ivoire     Tiassale
# 1134  AY0082-C       Tia_aPM_29      CIcol  Cote d'Ivoire     Tiassale
# 1135  AY0083-C        Tia_dPM_1      CIcol  Cote d'Ivoire     Tiassale
# 1136  AY0085-C       Tia_dPM_31      CIcol  Cote d'Ivoire     Tiassale
# 1137  AY0087-C       Tia_dPM_46      CIcol  Cote d'Ivoire     Tiassale
# 1138  AY0088-C       Tia_dPM_52      CIcol  Cote d'Ivoire     Tiassale
# 1139  AY0089-C        Tia_aPM_4      CIcol  Cote d'Ivoire     Tiassale
# 1140  AY0090-C       Tia_aPM_13      CIcol  Cote d'Ivoire     Tiassale
# 1141  AY0091-C       Tia_aPM_37      CIcol  Cote d'Ivoire     Tiassale
#
#              site    contributor        contact  year m_s sex  n_sequences  \
# 0     Twifo Praso  David Weetman  David Weetman  2012   M   F     95033368
# 1     Twifo Praso  David Weetman  David Weetman  2012   M   F     95843804
# 2        Takoradi  David Weetman  David Weetman  2012   M   F    107420666
# 3        Takoradi  David Weetman  David Weetman  2012   M   F     95993752
# 4        Takoradi  David Weetman  David Weetman  2012   M   F    103044262
# 5          Madina  David Weetman  David Weetman  2012   S   F    101183648
# 6          Madina  David Weetman  David Weetman  2012   M   F    106641272
# 7          Madina  David Weetman  David Weetman  2012   S   F     93961924
# 8     Twifo Praso  David Weetman  David Weetman  2012   M   F     99910300
# 9     Twifo Praso  David Weetman  David Weetman  2012   M   F    100899280
# 10    Twifo Praso  David Weetman  David Weetman  2012   M   F    104791234
# 11       Takoradi  David Weetman  David Weetman  2012   M   F     94902576
# 12       Takoradi  David Weetman  David Weetman  2012   M   F     95721108
# 13       Takoradi  David Weetman  David Weetman  2012   M   F    102828780
# 14         Madina  David Weetman  David Weetman  2012   S   F     90534918
# 15         Madina  David Weetman  David Weetman  2012   S   F     91137592
# 16    Twifo Praso  David Weetman  David Weetman  2012   M   F     90062282
# 17    Twifo Praso  David Weetman  David Weetman  2012   M   F    100028190
# 18       Takoradi  David Weetman  David Weetman  2012   M   F     86749914
# 19       Takoradi  David Weetman  David Weetman  2012   M   F    101513748
# 20       Takoradi  David Weetman  David Weetman  2012   M   F     97448404
# 21         Madina  David Weetman  David Weetman  2012   S   F     97192268
# 22         Madina  David Weetman  David Weetman  2012   M   F    100703586
# 23         Madina  David Weetman  David Weetman  2012   M   F    104975078
# 24    Twifo Praso  David Weetman  David Weetman  2012   M   F     98566392
# 25    Twifo Praso  David Weetman  David Weetman  2012   M   F     92182496
# 26    Twifo Praso  David Weetman  David Weetman  2012   M   F     89362286
# 27       Takoradi  David Weetman  David Weetman  2012   M   F    102825240
# 28         Madina  David Weetman  David Weetman  2012   S   F    104241714
# 29         Madina  David Weetman  David Weetman  2012   S   F    100752712
# ...           ...            ...            ...   ...  ..  ..          ...
# 1112     Tiassale  David Weetman  David Weetman  2012   M   F    105331900
# 1113     Tiassale  David Weetman  David Weetman  2012   M   F    103424408
# 1114     Tiassale  David Weetman  David Weetman  2012   M   F     94239280
# 1115     Tiassale  David Weetman  David Weetman  2012   M   F     90387728
# 1116     Tiassale  David Weetman  David Weetman  2012   M   F     95129228
# 1117     Tiassale  David Weetman  David Weetman  2012   M   F     93685638
# 1118     Tiassale  David Weetman  David Weetman  2012   M   F    102271052
# 1119     Tiassale  David Weetman  David Weetman  2012   M   F     95855540
# 1120     Tiassale  David Weetman  David Weetman  2012   M   F     93234608
# 1121     Tiassale  David Weetman  David Weetman  2012   M   F     99574902
# 1122     Tiassale  David Weetman  David Weetman  2012   M   F    100712030
# 1123     Tiassale  David Weetman  David Weetman  2012   M   F     96175126
# 1124     Tiassale  David Weetman  David Weetman  2012   M   F     95617762
# 1125     Tiassale  David Weetman  David Weetman  2012   M   F     99354268
# 1126     Tiassale  David Weetman  David Weetman  2012   M   F     92689602
# 1127     Tiassale  David Weetman  David Weetman  2012   M   F     98344274
# 1128     Tiassale  David Weetman  David Weetman  2012   M   F    100923050
# 1129     Tiassale  David Weetman  David Weetman  2012   M   F     89669580
# 1130     Tiassale  David Weetman  David Weetman  2012   M   F     99024338
# 1131     Tiassale  David Weetman  David Weetman  2012   M   F    101034336
# 1132     Tiassale  David Weetman  David Weetman  2012   M   F     98759958
# 1133     Tiassale  David Weetman  David Weetman  2012   M   F     97640586
# 1134     Tiassale  David Weetman  David Weetman  2012   M   F     98382152
# 1135     Tiassale  David Weetman  David Weetman  2012   M   F     93259480
# 1136     Tiassale  David Weetman  David Weetman  2012   M   F    109173728
# 1137     Tiassale  David Weetman  David Weetman  2012   M   F    101458232
# 1138     Tiassale  David Weetman  David Weetman  2012   M   F     95140584
# 1139     Tiassale  David Weetman  David Weetman  2012   M   F     92383724
# 1140     Tiassale  David Weetman  David Weetman  2012   M   F     96210618
# 1141     Tiassale  David Weetman  David Weetman  2012   M   F     95973872
#
#       mean_coverage ebi_sample_acc  latitude  longitude
# 0             30.99      ERS311878   5.60858   -1.54926
# 1             31.70      ERS311886   5.60858   -1.54926
# 2             35.65      ERS311894   4.91217   -1.77397
# 3             29.46      ERS311902   4.91217   -1.77397
# 4             33.67      ERS311910   4.91217   -1.77397
# 5             32.64      ERS311942   5.66849   -0.21928
# 6             32.84      ERS311950   5.66849   -0.21928
# 7             29.82      ERS311958   5.66849   -0.21928
# 8             33.33      ERS311871   5.60858   -1.54926
# 9             32.29      ERS311879   5.60858   -1.54926
# 10            34.14      ERS311887   5.60858   -1.54926
# 11            30.38      ERS311895   4.91217   -1.77397
# 12            30.93      ERS311903   4.91217   -1.77397
# 13            31.52      ERS311911   4.91217   -1.77397
# 14            29.46      ERS311943   5.66849   -0.21928
# 15            29.45      ERS311951   5.66849   -0.21928
# 16            29.33      ERS311872   5.60858   -1.54926
# 17            31.61      ERS311880   5.60858   -1.54926
# 18            27.43      ERS311896   4.91217   -1.77397
# 19            32.58      ERS311904   4.91217   -1.77397
# 20            31.42      ERS311912   4.91217   -1.77397
# 21            29.31      ERS311944   5.66849   -0.21928
# 22            33.75      ERS311952   5.66849   -0.21928
# 23            33.95      ERS311960   5.66849   -0.21928
# 24            31.67      ERS311873   5.60858   -1.54926
# 25            29.91      ERS311881   5.60858   -1.54926
# 26            27.69      ERS311889   5.60858   -1.54926
# 27            31.97      ERS311913   4.91217   -1.77397
# 28            34.36      ERS311945   5.66849   -0.21928
# 29            31.84      ERS311953   5.66849   -0.21928
# ...             ...            ...       ...        ...
# 1112          34.18      ERS311835   5.89839   -4.82293
# 1113          33.33      ERS311843   5.89839   -4.82293
# 1114          29.54      ERS311851   5.89839   -4.82293
# 1115          27.93      ERS311859   5.89839   -4.82293
# 1116          31.05      ERS311867   5.89839   -4.82293
# 1117          29.54      ERS311788   5.89839   -4.82293
# 1118          31.96      ERS311796   5.89839   -4.82293
# 1119          29.92      ERS311804   5.89839   -4.82293
# 1120          30.11      ERS311812   5.89839   -4.82293
# 1121          30.24      ERS311820   5.89839   -4.82293
# 1122          29.32      ERS311828   5.89839   -4.82293
# 1123          30.90      ERS311836   5.89839   -4.82293
# 1124          30.58      ERS311844   5.89839   -4.82293
# 1125          32.02      ERS311852   5.89839   -4.82293
# 1126          30.40      ERS311860   5.89839   -4.82293
# 1127          32.24      ERS311789   5.89839   -4.82293
# 1128          33.28      ERS311805   5.89839   -4.82293
# 1129          27.58      ERS311821   5.89839   -4.82293
# 1130          31.01      ERS311829   5.89839   -4.82293
# 1131          32.38      ERS311837   5.89839   -4.82293
# 1132          32.04      ERS311845   5.89839   -4.82293
# 1133          31.29      ERS311853   5.89839   -4.82293
# 1134          31.22      ERS311869   5.89839   -4.82293
# 1135          30.57      ERS311790   5.89839   -4.82293
# 1136          33.36      ERS311806   5.89839   -4.82293
# 1137          32.56      ERS311822   5.89839   -4.82293
# 1138          30.75      ERS311830   5.89839   -4.82293
# 1139          29.04      ERS311838   5.89839   -4.82293
# 1140          30.94      ERS311846   5.89839   -4.82293
# 1141          31.30      ERS311854   5.89839   -4.82293
#
# [1142 rows x 16 columns]

# %%
fasta_fn = 'D:\Genomes\genome\Anopheles-gambiae-PEST_CHROMOSOMES_AgamP4.fa'
genome = pyfasta.Fasta(fasta_fn, key_fn=lambda k: k.split()[0])

# %%
sorted(genome.keys())
# Out:
# ['2L', '2R', '3L', '3R', 'UNKN', 'X', 'Y_unplaced']

# %%
accessibility_fn = 'D:\Genomes\Genomes\extras\accessibility.h5'
accessibility = h5py.File(accessibility_fn, mode='r')

# %%
phase2happath = 'D:/Genomes/variation/ag1000g.phase2.ar1.haplotypes/'

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# ## DXY pairwise calc

# %% [markdown]
# Setting output folder, where my distances will be stored:

# %%
dist_dn_template = os.path.join('/mnt/70D89269D8922CFA/Genomes/extras/dist_haps')
dist_fn_template = '{chrom}.{start:08d}.{stop:08d}.npy'

# %% [markdown]
# Define function for distances calculations:

# %%
def compute_dxy_distance_matrices(chrom, window_size):
    dist_dn = dist_dn_template.format(metric='dxy', window_size=window_size)
    if not os.path.exists(dist_dn):
        os.makedirs(dist_dn)
        
    # open haplotypes
    callset = zarr.open(phase2happath)
    
    # load accessibility map
    is_accessible = accessibility[chrom]['is_accessible'][:]
    
    # determine accessible positions
    pos_accessible, = np.nonzero(is_accessible)
    
    # define equally accessible windows
    window_starts = pos_accessible[0:None:window_size]
    window_stops = pos_accessible[window_size-1:None:window_size]
    
    # add final window to end of chromosome
    window_starts = np.append(window_starts, [window_stops[-1] + 1])
    window_stops = np.append(window_stops, [len(genome[chrom])])
    
    # load variant positions
    pos = allel.SortedIndex(calldata_hap_phase2[chrom]['variants']['POS'][:])

    # iterate over windows
    for window_start, window_stop in zip(window_starts, window_stops):
        
        # distance matrix file name
        dist_fn = dist_fn_template.format(chrom=chrom, start=window_start, stop=window_stop)
        dist_path = os.path.join(dist_dn, dist_fn)
        
        # stay dry
        if os.path.exists(dist_path):
            log('skipping', dist_path)
            
        else:
            log('building', dist_path)
            gc.collect()
            
            with timer():
                
                # locate the window
                loc = pos.locate_range(window_start, window_stop)
                print (loc.start, loc.stop)

                # load data
                genotypes_phase2_call = calldata_hap_phase2[chrom]["calldata/GT"]
                genotypes_phase2 = allel.GenotypeChunkedArray(genotypes_phase2_call[loc])
                haplotypes = genotypes_phase2.to_haplotypes()
                n_variants = genotypes_phase2.shape[0]
                log('variants:', n_variants)


                # compute hamming distance
                dist = allel.pairwise_distance(haplotypes[:], metric='hamming')
                log('hamming distance, max:', dist.max(), ', min:', dist.min())

                # adjust by accessible window size
                n_bases = np.count_nonzero(is_accessible[window_start:window_stop+1])
                log('window accessible size:', n_bases)
                dist = dist * n_variants / n_bases
                log('dxy distance, max:', dist.max(), ', min:', dist.min())

                # save
                np.save(dist_path, dist)

# %% [markdown]
# Calculate distances on the two comosomal arm 3L and 3R with 100kbp windows:

# %%
dxy_3L = compute_dxy_distance_matrices('3L', 100000)
# Out:
# skipping dist_haps/3L.00009778.00730787.npy
# skipping dist_haps/3L.00730788.01243275.npy
# skipping dist_haps/3L.01243276.01622713.npy
# skipping dist_haps/3L.01622714.01833911.npy
# skipping dist_haps/3L.01833912.01989789.npy
# skipping dist_haps/3L.01989790.02108439.npy
# skipping dist_haps/3L.02108440.02239834.npy
# skipping dist_haps/3L.02239835.02412740.npy
# skipping dist_haps/3L.02412741.02586161.npy
# skipping dist_haps/3L.02586162.02773590.npy
# skipping dist_haps/3L.02773591.02919374.npy
# skipping dist_haps/3L.02919375.03073996.npy
# skipping dist_haps/3L.03073997.03235327.npy
# skipping dist_haps/3L.03235328.03378695.npy
# skipping dist_haps/3L.03378696.03487521.npy
# skipping dist_haps/3L.03487522.03595558.npy
# skipping dist_haps/3L.03595559.03719733.npy
# skipping dist_haps/3L.03719734.03884028.npy
# skipping dist_haps/3L.03884029.04028601.npy
# skipping dist_haps/3L.04028602.04210838.npy
# skipping dist_haps/3L.04210839.04880931.npy
# skipping dist_haps/3L.04880932.05102740.npy
# skipping dist_haps/3L.05102741.05235705.npy
# skipping dist_haps/3L.05235706.05365178.npy
# skipping dist_haps/3L.05365179.05483457.npy
# skipping dist_haps/3L.05483458.05625495.npy
# skipping dist_haps/3L.05625496.05737017.npy
# skipping dist_haps/3L.05737018.05881601.npy
# skipping dist_haps/3L.05881602.06017657.npy
# skipping dist_haps/3L.06017658.06216419.npy
# skipping dist_haps/3L.06216420.06382190.npy
# skipping dist_haps/3L.06382191.06520260.npy
# skipping dist_haps/3L.06520261.06644665.npy
# skipping dist_haps/3L.06644666.06755290.npy
# skipping dist_haps/3L.06755291.06925256.npy
# skipping dist_haps/3L.06925257.07088331.npy
# skipping dist_haps/3L.07088332.07587910.npy
# skipping dist_haps/3L.07587911.07857298.npy
# skipping dist_haps/3L.07857299.08050226.npy
# skipping dist_haps/3L.08050227.08237500.npy
# skipping dist_haps/3L.08237501.08395362.npy
# skipping dist_haps/3L.08395363.08549475.npy
# skipping dist_haps/3L.08549476.08712021.npy
# skipping dist_haps/3L.08712022.08865511.npy
# skipping dist_haps/3L.08865512.09050975.npy
# skipping dist_haps/3L.09050976.09325355.npy
# skipping dist_haps/3L.09325356.09536254.npy
# skipping dist_haps/3L.09536255.09764795.npy
# skipping dist_haps/3L.09764796.10052370.npy
# skipping dist_haps/3L.10052371.10247115.npy
# skipping dist_haps/3L.10247116.10426849.npy
# skipping dist_haps/3L.10426850.10561494.npy
# skipping dist_haps/3L.10561495.10736246.npy
# skipping dist_haps/3L.10736247.10984318.npy
# skipping dist_haps/3L.10984319.11243540.npy
# skipping dist_haps/3L.11243541.11403351.npy
# skipping dist_haps/3L.11403352.11659888.npy
# skipping dist_haps/3L.11659889.11803067.npy
# skipping dist_haps/3L.11803068.11940440.npy
# skipping dist_haps/3L.11940441.12103702.npy
# skipping dist_haps/3L.12103703.12259501.npy
# skipping dist_haps/3L.12259502.12441862.npy
# skipping dist_haps/3L.12441863.12564241.npy
# skipping dist_haps/3L.12564242.12723243.npy
# skipping dist_haps/3L.12723244.12875229.npy
# skipping dist_haps/3L.12875230.13058254.npy
# skipping dist_haps/3L.13058255.13227049.npy
# skipping dist_haps/3L.13227050.13373523.npy
# skipping dist_haps/3L.13373524.13515094.npy
# skipping dist_haps/3L.13515095.13678806.npy
# skipping dist_haps/3L.13678807.14023032.npy
# skipping dist_haps/3L.14023033.14160413.npy
# skipping dist_haps/3L.14160414.14291835.npy
# skipping dist_haps/3L.14291836.14441043.npy
# skipping dist_haps/3L.14441044.14639275.npy
# skipping dist_haps/3L.14639276.14785313.npy
# skipping dist_haps/3L.14785314.14954328.npy
# skipping dist_haps/3L.14954329.15103198.npy
# skipping dist_haps/3L.15103199.15243398.npy
# skipping dist_haps/3L.15243399.15396152.npy
# skipping dist_haps/3L.15396153.15599366.npy
# skipping dist_haps/3L.15599367.15809512.npy
# skipping dist_haps/3L.15809513.16103927.npy
# skipping dist_haps/3L.16103928.16361839.npy
# skipping dist_haps/3L.16361840.16490837.npy
# skipping dist_haps/3L.16490838.16638552.npy
# skipping dist_haps/3L.16638553.16771269.npy
# skipping dist_haps/3L.16771270.16898075.npy
# skipping dist_haps/3L.16898076.17018132.npy
# skipping dist_haps/3L.17018133.17150857.npy
# skipping dist_haps/3L.17150858.17281898.npy
# skipping dist_haps/3L.17281899.17410434.npy
# skipping dist_haps/3L.17410435.17564217.npy
# skipping dist_haps/3L.17564218.17731078.npy
# skipping dist_haps/3L.17731093.17887067.npy
# skipping dist_haps/3L.17887068.18080804.npy
# skipping dist_haps/3L.18080805.18225381.npy
# skipping dist_haps/3L.18225382.18358940.npy
# skipping dist_haps/3L.18358941.18480421.npy
# skipping dist_haps/3L.18480422.18602687.npy
# skipping dist_haps/3L.18602688.18743162.npy
# skipping dist_haps/3L.18743163.18892316.npy
# skipping dist_haps/3L.18892317.19031336.npy
# skipping dist_haps/3L.19031337.19186494.npy
# skipping dist_haps/3L.19186495.19325810.npy
# skipping dist_haps/3L.19325811.19458149.npy
# skipping dist_haps/3L.19458150.19596733.npy
# skipping dist_haps/3L.19596734.19743051.npy
# skipping dist_haps/3L.19743052.19885167.npy
# skipping dist_haps/3L.19885168.20066797.npy
# skipping dist_haps/3L.20066798.20208736.npy
# skipping dist_haps/3L.20208737.20492857.npy
# skipping dist_haps/3L.20492858.20646917.npy
# skipping dist_haps/3L.20646918.20802578.npy
# skipping dist_haps/3L.20802579.20994441.npy
# skipping dist_haps/3L.20994442.21178560.npy
# skipping dist_haps/3L.21178561.21325309.npy
# skipping dist_haps/3L.21325310.21487066.npy
# skipping dist_haps/3L.21487067.21672372.npy
# skipping dist_haps/3L.21672373.21834102.npy
# skipping dist_haps/3L.21834103.22052592.npy
# skipping dist_haps/3L.22052593.22205784.npy
# skipping dist_haps/3L.22205785.22364726.npy
# skipping dist_haps/3L.22364727.22538185.npy
# skipping dist_haps/3L.22538186.22679486.npy
# skipping dist_haps/3L.22679487.22849618.npy
# skipping dist_haps/3L.22849619.22977573.npy
# skipping dist_haps/3L.22977574.23155391.npy
# skipping dist_haps/3L.23155392.23465473.npy
# skipping dist_haps/3L.23465474.23638853.npy
# skipping dist_haps/3L.23638854.23780782.npy
# skipping dist_haps/3L.23780783.24002023.npy
# skipping dist_haps/3L.24002024.24150191.npy
# skipping dist_haps/3L.24150192.24301639.npy
# skipping dist_haps/3L.24301640.24488790.npy
# skipping dist_haps/3L.24488791.24773539.npy
# skipping dist_haps/3L.24773540.24912301.npy
# skipping dist_haps/3L.24912302.25046500.npy
# skipping dist_haps/3L.25046501.25204812.npy
# skipping dist_haps/3L.25204813.25376351.npy
# skipping dist_haps/3L.25376352.25594163.npy
# skipping dist_haps/3L.25594164.25782934.npy
# skipping dist_haps/3L.25782935.25936689.npy
# skipping dist_haps/3L.25936690.26089152.npy
# skipping dist_haps/3L.26089153.26249284.npy
# skipping dist_haps/3L.26249285.26406521.npy
# skipping dist_haps/3L.26406522.26616594.npy
# skipping dist_haps/3L.26616595.26761344.npy
# skipping dist_haps/3L.26761345.26986065.npy
# skipping dist_haps/3L.26986066.27146101.npy
# skipping dist_haps/3L.27146102.27300426.npy
# skipping dist_haps/3L.27300427.27427839.npy
# skipping dist_haps/3L.27427840.27562911.npy
# skipping dist_haps/3L.27562912.27715681.npy
# skipping dist_haps/3L.27715682.27851069.npy
# skipping dist_haps/3L.27851070.28001726.npy
# skipping dist_haps/3L.28001727.28165393.npy
# skipping dist_haps/3L.28165394.28320990.npy
# skipping dist_haps/3L.28320991.28497460.npy
# skipping dist_haps/3L.28497461.28688682.npy
# skipping dist_haps/3L.28688683.28867194.npy
# skipping dist_haps/3L.28867195.29012023.npy
# skipping dist_haps/3L.29012024.29205947.npy
# skipping dist_haps/3L.29205948.29375534.npy
# skipping dist_haps/3L.29375535.29518354.npy
# skipping dist_haps/3L.29518355.29651426.npy
# skipping dist_haps/3L.29651427.29779069.npy
# skipping dist_haps/3L.29779070.29912932.npy
# skipping dist_haps/3L.29912933.30084912.npy
# skipping dist_haps/3L.30084913.30242151.npy
# skipping dist_haps/3L.30242152.30379246.npy
# skipping dist_haps/3L.30379247.30522890.npy
# skipping dist_haps/3L.30522891.30671270.npy
# skipping dist_haps/3L.30671271.30822456.npy
# skipping dist_haps/3L.30822457.30958674.npy
# skipping dist_haps/3L.30958675.31169313.npy
# skipping dist_haps/3L.31169314.31347816.npy
# skipping dist_haps/3L.31347817.31477133.npy
# skipping dist_haps/3L.31477134.31621018.npy
# skipping dist_haps/3L.31621019.31776425.npy
# skipping dist_haps/3L.31776426.31940279.npy
# skipping dist_haps/3L.31940317.32124771.npy
# skipping dist_haps/3L.32124772.32299202.npy
# skipping dist_haps/3L.32299203.32443821.npy
# skipping dist_haps/3L.32443822.32581187.npy
# skipping dist_haps/3L.32581188.32711124.npy
# skipping dist_haps/3L.32711125.32862422.npy
# skipping dist_haps/3L.32862423.33012913.npy
# skipping dist_haps/3L.33012914.33179570.npy
# skipping dist_haps/3L.33179571.33338926.npy
# skipping dist_haps/3L.33338927.33494388.npy
# skipping dist_haps/3L.33494389.33663844.npy
# skipping dist_haps/3L.33663845.33816339.npy
# skipping dist_haps/3L.33816340.33953393.npy
# skipping dist_haps/3L.33953394.34089926.npy
# skipping dist_haps/3L.34089927.34250571.npy
# skipping dist_haps/3L.34250572.34392770.npy
# skipping dist_haps/3L.34392771.34529190.npy
# skipping dist_haps/3L.34529191.34659839.npy
# skipping dist_haps/3L.34659840.34796001.npy
# skipping dist_haps/3L.34796002.34956052.npy
# skipping dist_haps/3L.34956053.35108978.npy
# skipping dist_haps/3L.35108979.35268384.npy
# skipping dist_haps/3L.35268385.35413768.npy
# skipping dist_haps/3L.35413769.35548311.npy
# skipping dist_haps/3L.35548312.35704009.npy
# skipping dist_haps/3L.35704010.35867495.npy
# skipping dist_haps/3L.35867496.35994433.npy
# skipping dist_haps/3L.35994434.36146491.npy
# skipping dist_haps/3L.36146492.36333928.npy
# skipping dist_haps/3L.36333929.36671226.npy
# skipping dist_haps/3L.36671227.36834792.npy
# skipping dist_haps/3L.36834793.36965450.npy
# skipping dist_haps/3L.36965451.37103480.npy
# skipping dist_haps/3L.37103481.37274319.npy
# skipping dist_haps/3L.37274320.37500102.npy
# skipping dist_haps/3L.37500103.37668764.npy
# skipping dist_haps/3L.37668765.37801326.npy
# skipping dist_haps/3L.37801327.37963363.npy
# skipping dist_haps/3L.37963364.38108736.npy
# skipping dist_haps/3L.38108737.38268654.npy
# skipping dist_haps/3L.38268655.38406774.npy
# skipping dist_haps/3L.38406775.38551394.npy
# skipping dist_haps/3L.38551395.38762976.npy
# skipping dist_haps/3L.38762977.38894431.npy
# skipping dist_haps/3L.38894432.39031847.npy
# skipping dist_haps/3L.39031848.39199498.npy
# skipping dist_haps/3L.39199499.39319965.npy
# skipping dist_haps/3L.39319966.39437304.npy
# skipping dist_haps/3L.39437305.39550783.npy
# skipping dist_haps/3L.39550784.39714706.npy
# skipping dist_haps/3L.39714707.39828654.npy
# skipping dist_haps/3L.39828655.39956033.npy
# skipping dist_haps/3L.39956034.40077396.npy
# skipping dist_haps/3L.40077397.40204601.npy
# skipping dist_haps/3L.40204602.40317283.npy
# skipping dist_haps/3L.40317284.40448243.npy
# skipping dist_haps/3L.40448244.40558009.npy
# skipping dist_haps/3L.40558010.40667358.npy
# skipping dist_haps/3L.40667359.40790863.npy
# skipping dist_haps/3L.40790864.40922676.npy
# skipping dist_haps/3L.40922677.41073749.npy
# skipping dist_haps/3L.41073750.41209522.npy
# skipping dist_haps/3L.41209523.41316194.npy
# skipping dist_haps/3L.41316195.41421501.npy
# skipping dist_haps/3L.41421502.41527085.npy
# skipping dist_haps/3L.41527086.41636061.npy
# skipping dist_haps/3L.41636062.41752251.npy
# skipping dist_haps/3L.41752252.41885923.npy
# skipping dist_haps/3L.41885924.41963435.npy

# %%
dxy_3R = compute_dxy_distance_matrices('3R', 100000)
# Out:
# skipping dist_haps/3R.00000020.00134416.npy
# skipping dist_haps/3R.00134417.00243509.npy
# skipping dist_haps/3R.00243510.00352301.npy
# skipping dist_haps/3R.00352302.00473621.npy
# skipping dist_haps/3R.00473622.00577607.npy
# skipping dist_haps/3R.00577608.00690433.npy
# skipping dist_haps/3R.00690434.00801223.npy
# skipping dist_haps/3R.00801224.00915204.npy
# skipping dist_haps/3R.00915205.01030193.npy
# skipping dist_haps/3R.01030194.01147657.npy
# skipping dist_haps/3R.01147658.01270736.npy
# skipping dist_haps/3R.01270737.01395739.npy
# skipping dist_haps/3R.01395740.01525501.npy
# skipping dist_haps/3R.01525502.01647090.npy
# skipping dist_haps/3R.01647091.01767431.npy
# skipping dist_haps/3R.01767432.01903815.npy
# skipping dist_haps/3R.01903816.02013366.npy
# skipping dist_haps/3R.02013367.02125220.npy
# skipping dist_haps/3R.02125221.02333172.npy
# skipping dist_haps/3R.02333173.02447612.npy
# skipping dist_haps/3R.02447613.02564468.npy
# skipping dist_haps/3R.02564469.02677460.npy
# skipping dist_haps/3R.02677461.02800576.npy
# skipping dist_haps/3R.02800577.02917557.npy
# skipping dist_haps/3R.02917558.03062142.npy
# skipping dist_haps/3R.03062143.03198738.npy
# skipping dist_haps/3R.03198739.03321424.npy
# skipping dist_haps/3R.03321425.03461046.npy
# skipping dist_haps/3R.03461047.03576299.npy
# skipping dist_haps/3R.03576300.03687319.npy
# skipping dist_haps/3R.03687320.03797583.npy
# skipping dist_haps/3R.03797584.03906853.npy
# skipping dist_haps/3R.03906854.04020817.npy
# skipping dist_haps/3R.04020818.04130174.npy
# skipping dist_haps/3R.04130175.04257141.npy
# skipping dist_haps/3R.04257142.04378556.npy
# skipping dist_haps/3R.04378557.04503124.npy
# skipping dist_haps/3R.04503125.04617156.npy
# skipping dist_haps/3R.04617157.04733950.npy
# skipping dist_haps/3R.04733951.04853279.npy
# skipping dist_haps/3R.04853280.04979261.npy
# skipping dist_haps/3R.04979262.05103569.npy
# skipping dist_haps/3R.05103570.05225460.npy
# skipping dist_haps/3R.05225461.05342949.npy
# skipping dist_haps/3R.05342950.05454056.npy
# skipping dist_haps/3R.05454057.05563635.npy
# skipping dist_haps/3R.05563636.05681307.npy
# skipping dist_haps/3R.05681308.05789126.npy
# skipping dist_haps/3R.05789127.05952355.npy
# skipping dist_haps/3R.05952356.06094035.npy
# skipping dist_haps/3R.06094036.06246826.npy
# skipping dist_haps/3R.06246827.06388626.npy
# skipping dist_haps/3R.06388627.06551034.npy
# skipping dist_haps/3R.06551035.06667381.npy
# skipping dist_haps/3R.06667382.06791243.npy
# skipping dist_haps/3R.06791244.06933252.npy
# skipping dist_haps/3R.06933253.07097461.npy
# skipping dist_haps/3R.07097462.07216181.npy
# skipping dist_haps/3R.07216182.07331341.npy
# skipping dist_haps/3R.07331342.07462948.npy
# skipping dist_haps/3R.07462949.07591035.npy
# skipping dist_haps/3R.07591036.07710961.npy
# skipping dist_haps/3R.07710962.07936252.npy
# skipping dist_haps/3R.07936253.08111987.npy
# skipping dist_haps/3R.08111988.08226707.npy
# skipping dist_haps/3R.08226708.08338904.npy
# skipping dist_haps/3R.08338905.08468844.npy
# skipping dist_haps/3R.08468845.08586836.npy
# skipping dist_haps/3R.08586837.08708649.npy
# skipping dist_haps/3R.08708650.08842612.npy
# skipping dist_haps/3R.08842613.08962698.npy
# skipping dist_haps/3R.08962699.09113763.npy
# skipping dist_haps/3R.09113764.09265437.npy
# skipping dist_haps/3R.09265438.09379401.npy
# skipping dist_haps/3R.09379402.09497536.npy
# skipping dist_haps/3R.09497537.09622773.npy
# skipping dist_haps/3R.09622774.09764191.npy
# skipping dist_haps/3R.09764192.09980409.npy
# skipping dist_haps/3R.09980410.10102807.npy
# skipping dist_haps/3R.10102808.10223293.npy
# skipping dist_haps/3R.10223294.10348635.npy
# skipping dist_haps/3R.10348636.10492204.npy
# skipping dist_haps/3R.10492205.10613358.npy
# skipping dist_haps/3R.10613359.10762300.npy
# skipping dist_haps/3R.10762301.10941093.npy
# skipping dist_haps/3R.10941094.11148865.npy
# skipping dist_haps/3R.11148866.11267974.npy
# skipping dist_haps/3R.11267975.11408787.npy
# skipping dist_haps/3R.11408788.11593450.npy
# skipping dist_haps/3R.11593451.11762854.npy
# skipping dist_haps/3R.11762855.12013728.npy
# skipping dist_haps/3R.12013729.12284595.npy
# skipping dist_haps/3R.12284596.12542178.npy
# skipping dist_haps/3R.12542179.12704719.npy
# skipping dist_haps/3R.12704720.12872898.npy
# skipping dist_haps/3R.12872899.13020002.npy
# skipping dist_haps/3R.13020003.13197674.npy
# skipping dist_haps/3R.13197675.13356793.npy
# skipping dist_haps/3R.13356794.13531088.npy
# skipping dist_haps/3R.13531089.13694073.npy
# skipping dist_haps/3R.13694074.13830896.npy
# skipping dist_haps/3R.13830897.14003821.npy
# skipping dist_haps/3R.14003822.14199427.npy
# skipping dist_haps/3R.14199428.14420695.npy
# skipping dist_haps/3R.14420696.14625598.npy
# skipping dist_haps/3R.14625599.14832916.npy
# skipping dist_haps/3R.14832917.15013884.npy
# skipping dist_haps/3R.15013885.15191157.npy
# skipping dist_haps/3R.15191158.15399756.npy
# skipping dist_haps/3R.15399757.15577280.npy
# skipping dist_haps/3R.15577281.15722934.npy
# skipping dist_haps/3R.15722935.15907783.npy
# skipping dist_haps/3R.15907784.16091707.npy
# skipping dist_haps/3R.16091708.16275500.npy
# skipping dist_haps/3R.16275501.16475256.npy
# skipping dist_haps/3R.16475257.16648957.npy
# skipping dist_haps/3R.16648958.16808041.npy
# skipping dist_haps/3R.16808042.17056838.npy
# skipping dist_haps/3R.17056839.17238745.npy
# skipping dist_haps/3R.17238746.17413268.npy
# skipping dist_haps/3R.17413269.17562592.npy
# skipping dist_haps/3R.17562593.17725130.npy
# skipping dist_haps/3R.17725131.17876171.npy
# skipping dist_haps/3R.17876172.18010304.npy
# skipping dist_haps/3R.18010305.18161898.npy
# skipping dist_haps/3R.18161899.18305602.npy
# skipping dist_haps/3R.18305603.18444432.npy
# skipping dist_haps/3R.18444433.18576112.npy
# skipping dist_haps/3R.18576113.18980625.npy
# skipping dist_haps/3R.18980626.19124528.npy
# skipping dist_haps/3R.19124529.19303763.npy
# skipping dist_haps/3R.19303764.19454250.npy
# skipping dist_haps/3R.19454251.19665799.npy
# skipping dist_haps/3R.19665800.19842045.npy
# skipping dist_haps/3R.19842046.20006631.npy
# skipping dist_haps/3R.20006632.20195026.npy
# skipping dist_haps/3R.20195027.20372594.npy
# skipping dist_haps/3R.20372595.20564390.npy
# skipping dist_haps/3R.20564391.20734295.npy
# skipping dist_haps/3R.20734296.20883139.npy
# skipping dist_haps/3R.20883140.21046882.npy
# skipping dist_haps/3R.21046883.21222869.npy
# skipping dist_haps/3R.21222870.21420366.npy
# skipping dist_haps/3R.21420367.21580250.npy
# skipping dist_haps/3R.21580251.21697987.npy
# skipping dist_haps/3R.21697988.21871997.npy
# skipping dist_haps/3R.21871998.22028648.npy
# skipping dist_haps/3R.22028649.22186987.npy
# skipping dist_haps/3R.22186988.22323393.npy
# skipping dist_haps/3R.22323394.22459574.npy
# skipping dist_haps/3R.22459575.22603844.npy
# skipping dist_haps/3R.22603845.22757056.npy
# skipping dist_haps/3R.22757057.22897628.npy
# skipping dist_haps/3R.22897629.23055270.npy
# skipping dist_haps/3R.23055271.23204245.npy
# skipping dist_haps/3R.23204246.23364938.npy
# skipping dist_haps/3R.23364939.23536065.npy
# skipping dist_haps/3R.23536066.23808308.npy
# skipping dist_haps/3R.23808309.23994426.npy
# skipping dist_haps/3R.23994427.24174230.npy
# skipping dist_haps/3R.24174231.24367467.npy
# skipping dist_haps/3R.24367468.24536186.npy
# skipping dist_haps/3R.24536187.24654494.npy
# skipping dist_haps/3R.24654495.24797034.npy
# skipping dist_haps/3R.24797035.24998242.npy
# skipping dist_haps/3R.24998243.25138239.npy
# skipping dist_haps/3R.25138240.25392412.npy
# skipping dist_haps/3R.25392413.25508101.npy
# skipping dist_haps/3R.25508102.25627897.npy
# skipping dist_haps/3R.25627898.25774026.npy
# skipping dist_haps/3R.25774027.25896999.npy
# skipping dist_haps/3R.25897000.26026579.npy
# skipping dist_haps/3R.26026580.26170389.npy
# skipping dist_haps/3R.26170390.26302294.npy
# skipping dist_haps/3R.26302295.26422816.npy
# skipping dist_haps/3R.26422817.26568158.npy
# skipping dist_haps/3R.26568159.26720905.npy
# skipping dist_haps/3R.26720906.26863283.npy
# skipping dist_haps/3R.26863284.27023929.npy
# skipping dist_haps/3R.27023930.27171372.npy
# skipping dist_haps/3R.27171373.27317738.npy
# skipping dist_haps/3R.27317739.27468000.npy
# skipping dist_haps/3R.27468001.27605739.npy
# skipping dist_haps/3R.27605740.27729611.npy
# skipping dist_haps/3R.27729612.27856633.npy
# skipping dist_haps/3R.27856634.27978792.npy
# skipping dist_haps/3R.27978793.28097674.npy
# skipping dist_haps/3R.28097675.28255108.npy
# skipping dist_haps/3R.28255109.28419773.npy
# skipping dist_haps/3R.28419774.28571981.npy
# skipping dist_haps/3R.28571982.28709642.npy
# skipping dist_haps/3R.28709643.28852739.npy
# skipping dist_haps/3R.28852740.28991327.npy
# skipping dist_haps/3R.28991328.29145313.npy
# skipping dist_haps/3R.29145314.29301706.npy
# skipping dist_haps/3R.29301707.29988961.npy
# skipping dist_haps/3R.29988962.30124220.npy
# skipping dist_haps/3R.30124221.30261487.npy
# skipping dist_haps/3R.30261488.30392844.npy
# skipping dist_haps/3R.30392845.30517852.npy
# skipping dist_haps/3R.30517853.30642065.npy
# skipping dist_haps/3R.30642066.30771775.npy
# skipping dist_haps/3R.30771776.30916952.npy
# skipping dist_haps/3R.30916953.31034644.npy
# skipping dist_haps/3R.31034645.31237122.npy
# skipping dist_haps/3R.31237123.31424666.npy
# skipping dist_haps/3R.31424667.31567398.npy
# skipping dist_haps/3R.31567399.31720583.npy
# skipping dist_haps/3R.31720584.31983362.npy
# skipping dist_haps/3R.31983363.32111521.npy
# skipping dist_haps/3R.32111522.32374204.npy
# skipping dist_haps/3R.32374205.32888007.npy
# skipping dist_haps/3R.32888008.33029637.npy
# skipping dist_haps/3R.33029638.33205474.npy
# skipping dist_haps/3R.33205475.33378014.npy
# skipping dist_haps/3R.33378015.33538344.npy
# skipping dist_haps/3R.33538345.33676731.npy
# skipping dist_haps/3R.33676732.33807866.npy
# skipping dist_haps/3R.33807867.34007445.npy
# skipping dist_haps/3R.34007446.34197987.npy
# skipping dist_haps/3R.34197988.34367137.npy
# skipping dist_haps/3R.34367138.34515328.npy
# skipping dist_haps/3R.34515329.34696150.npy
# skipping dist_haps/3R.34696151.34832726.npy
# skipping dist_haps/3R.34832727.34969763.npy
# skipping dist_haps/3R.34969764.35103240.npy
# skipping dist_haps/3R.35103241.35232765.npy
# skipping dist_haps/3R.35232766.35368053.npy
# skipping dist_haps/3R.35368054.35517761.npy
# skipping dist_haps/3R.35517762.35657218.npy
# skipping dist_haps/3R.35657219.35854499.npy
# skipping dist_haps/3R.35854500.36032138.npy
# skipping dist_haps/3R.36032139.36161398.npy
# skipping dist_haps/3R.36161399.36318733.npy
# skipping dist_haps/3R.36318734.36469660.npy
# skipping dist_haps/3R.36469661.36713138.npy
# skipping dist_haps/3R.36713139.36882387.npy
# skipping dist_haps/3R.36882388.37009981.npy
# skipping dist_haps/3R.37009982.37158602.npy
# skipping dist_haps/3R.37158603.37320183.npy
# skipping dist_haps/3R.37320184.37490121.npy
# skipping dist_haps/3R.37490122.37650650.npy
# skipping dist_haps/3R.37650651.37804672.npy
# skipping dist_haps/3R.37804673.37934384.npy
# skipping dist_haps/3R.37934385.38173741.npy
# skipping dist_haps/3R.38173742.38293597.npy
# skipping dist_haps/3R.38293598.38433970.npy
# skipping dist_haps/3R.38433971.38564607.npy
# skipping dist_haps/3R.38564608.38707411.npy
# skipping dist_haps/3R.38707412.38843375.npy
# skipping dist_haps/3R.38843384.38950886.npy
# skipping dist_haps/3R.38950887.39106958.npy
# skipping dist_haps/3R.39106959.39958443.npy
# skipping dist_haps/3R.39958444.40651386.npy
# skipping dist_haps/3R.40651387.41055360.npy
# skipping dist_haps/3R.41055361.41303904.npy
# skipping dist_haps/3R.41303905.41449165.npy
# skipping dist_haps/3R.41449166.41586061.npy
# skipping dist_haps/3R.41586062.41697648.npy
# skipping dist_haps/3R.41697649.41818573.npy
# skipping dist_haps/3R.41818574.41949435.npy
# skipping dist_haps/3R.41949436.42061020.npy
# skipping dist_haps/3R.42061021.42192853.npy
# skipping dist_haps/3R.42192854.42301099.npy
# skipping dist_haps/3R.42301100.42428915.npy
# skipping dist_haps/3R.42428916.42562131.npy
# skipping dist_haps/3R.42562132.42699013.npy
# skipping dist_haps/3R.42699014.42842157.npy
# skipping dist_haps/3R.42842158.42967780.npy
# skipping dist_haps/3R.42967781.43244724.npy
# skipping dist_haps/3R.43244725.43397895.npy
# skipping dist_haps/3R.43397896.43539675.npy
# skipping dist_haps/3R.43539676.43689308.npy
# skipping dist_haps/3R.43689309.43821262.npy
# skipping dist_haps/3R.43821263.44022792.npy
# skipping dist_haps/3R.44022793.44143566.npy
# skipping dist_haps/3R.44143567.44252381.npy
# skipping dist_haps/3R.44252382.44365196.npy
# skipping dist_haps/3R.44365197.44489397.npy
# skipping dist_haps/3R.44489398.44652090.npy
# skipping dist_haps/3R.44652091.44894375.npy
# skipping dist_haps/3R.44894376.45045994.npy
# skipping dist_haps/3R.45045995.45185559.npy
# skipping dist_haps/3R.45185560.45348379.npy
# skipping dist_haps/3R.45348380.45509036.npy
# skipping dist_haps/3R.45509037.45635946.npy
# skipping dist_haps/3R.45635947.45807519.npy
# skipping dist_haps/3R.45807520.46050577.npy
# skipping dist_haps/3R.46050578.46211344.npy
# skipping dist_haps/3R.46211345.46406759.npy
# skipping dist_haps/3R.46406760.46535448.npy
# skipping dist_haps/3R.46535449.46705667.npy
# skipping dist_haps/3R.46705668.46974563.npy
# skipping dist_haps/3R.46974564.47129499.npy
# skipping dist_haps/3R.47129500.47265784.npy
# skipping dist_haps/3R.47265785.47407687.npy
# skipping dist_haps/3R.47407688.47585662.npy
# skipping dist_haps/3R.47585663.47796755.npy
# skipping dist_haps/3R.47796756.47949002.npy
# skipping dist_haps/3R.47949003.48120072.npy
# skipping dist_haps/3R.48120073.48318016.npy
# skipping dist_haps/3R.48318017.48456992.npy
# skipping dist_haps/3R.48456993.48676034.npy
# skipping dist_haps/3R.48676035.48884938.npy
# skipping dist_haps/3R.48884939.49024436.npy
# skipping dist_haps/3R.49024437.49309489.npy
# skipping dist_haps/3R.49309490.49477683.npy
# skipping dist_haps/3R.49477684.49669622.npy
# skipping dist_haps/3R.49669623.49852560.npy
# skipping dist_haps/3R.49852561.50018131.npy
# skipping dist_haps/3R.50018132.50131530.npy
# skipping dist_haps/3R.50131531.50261873.npy
# skipping dist_haps/3R.50261874.50431869.npy
# skipping dist_haps/3R.50431870.50573439.npy
# skipping dist_haps/3R.50573440.50705914.npy
# skipping dist_haps/3R.50705915.50900017.npy
# skipping dist_haps/3R.50900018.51061543.npy
# skipping dist_haps/3R.51061544.51253426.npy
# skipping dist_haps/3R.51253427.51436364.npy
# skipping dist_haps/3R.51436365.51607764.npy
# skipping dist_haps/3R.51607765.51745771.npy
# skipping dist_haps/3R.51745772.51935615.npy
# skipping dist_haps/3R.51935616.52185263.npy
# skipping dist_haps/3R.52185264.52849107.npy
# skipping dist_haps/3R.52849108.53200684.npy

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## DXY plotting

# %%
palette = sns.color_palette()

# %%
distscan_dir = 'D:\Genomes\extras\dist_haps'

# %%
def open_dscan(chrom):

    # find the underlying matrix file names, we need these to get window boundaries
    dfns = sorted(glob.glob(os.path.join(distscan_dir, chrom + '*.npy')))
    bnms = [os.path.basename(f) for f in dfns]
    windows = np.array([[int(b.split('.')[1]), int(b.split('.')[2])] for b in bnms])
    n_windows = len(windows)
    log(n_windows, 'windows')

    # compile into a single array
    dscan_rootdir = os.path.join(distscan_dir, '%s.bcolz' % chrom)
    if not os.path.exists(dscan_rootdir):
        log('loading', dscan_rootdir)

        # load up the first matrix to determine shape
        d = np.load(dfns[0])
        n_pairs = d.shape[0]
        
        log(n_pairs, 'pairs')

        # setup bcolz array
        dscan = bcolz.carray(np.empty((0, n_pairs), dtype='f4'), 
                             cparams=bcolz.cparams(cname='zlib', clevel=1),
                             rootdir=dscan_rootdir,
                             mode='w',
                             expectedlen=n_windows)

        # load one row at a time
        for i, dfn in enumerate(dfns):
            if i > 0 and i % 20 == 0:
                log(i, dfn)
            dscan.append(np.load(dfn, mmap_mode='r'))
            dscan.flush()
        
    # open/re-open in read-only mode
    dscan = bcolz.carray(rootdir=dscan_rootdir, mode='r')

    return windows, dscan

# %%
def sample_to_haplotype_indices(sidx):
    return list(itertools.chain(*[[ix*2, ix*2+1] for ix in sidx]))

# %%
def extract_2pop_dscan(chrom, pop1, pop2):

    callset = zarr.group(phase2happath)
    samples = [str(s, 'ascii') for s in callset['samples'][:]]
    n_samples = len(samples)
    n_haplotypes = 2 * n_samples
    
    # load dscan
    windows, dscan = open_dscan(chrom)

    # locate sample indices
    pop1_sample_indices=tbl_samples.population[tbl_samples.population == pop1].index.tolist()
    pop2_sample_indices=tbl_samples.population[tbl_samples.population == pop2].index.tolist()

    # locate haplotype indices
    pop1_haplotype_indices = sample_to_haplotype_indices(pop1_sample_indices)
    pop2_haplotype_indices = sample_to_haplotype_indices(pop2_sample_indices)
    
    # locate indices of pairwise comparisons within and between populations
    dw1_ix = allel.condensed_coords_within(pop1_haplotype_indices, n_haplotypes)
    dw2_ix = allel.condensed_coords_within(pop2_haplotype_indices, n_haplotypes)
    db_ix = allel.condensed_coords_between(pop1_haplotype_indices, pop2_haplotype_indices, n_haplotypes)
    
    # extract pairwise distances
    dw1 = allel.chunked.core.take(dscan, dw1_ix, axis=1)[:]
    dw2 = allel.chunked.core.take(dscan, dw2_ix, axis=1)[:]
    db = allel.chunked.core.take(dscan, db_ix, axis=1)[:]
    
   
    return windows, dw1, dw2, db

# %%
def plot_dist_scan(windows, d, ylim=(0, 0.016), title=None, color=None, ax=None):
    
    # set up figure
    if ax is None:
        fig, ax = subplots(figsize=(8, 1.5))
    if title is not None:
        ax.set_title(title, fontweight='bold')

    # window centres
    x = np.array(windows).mean(axis=1)

    # median
    y = np.median(d, axis=1)
    ax.plot(x, y, color=color, lw=1)
    
    # interquartile range
    y1 = np.percentile(d, 25, axis=1)
    y2 = np.percentile(d, 75, axis=1)
    ax.fill_between(x, y1, y2, color=color, alpha=.6)
    
    # 5-95 range
    y1 = np.percentile(d, 5, axis=1)
    y2 = np.percentile(d, 95, axis=1)
    ax.fill_between(x, y1, y2, color=color, alpha=.4)
    
    # total range
    y1 = d.min(axis=1)
    y2 = d.max(axis=1)
    ax.fill_between(x, y1, y2, color=color, alpha=.2)
    
    # tidy up
    ax.set_ylim(*ylim)
    
    # legend
    handles = list()
    # median
    l = plt.Line2D([], [], color=color, linestyle='-', linewidth=2, label='median')
    handles.append(l)
    # percentiles
    r = plt.Rectangle([0, 0], 1, 1, color=color, alpha=.6, lw=0, label='25-75th percentiles')
    handles.append(r)
    r = plt.Rectangle([0, 0], 1, 1, color=color, alpha=.4, lw=0, label='5-95th percentiles')
    handles.append(r)
    r = plt.Rectangle([0, 0], 1, 1, color=color, alpha=.2, lw=0, label='min-max')
    handles.append(r)
    ax.legend(handles=handles, bbox_to_anchor=[1, 1], loc='upper left')    
    ax.set_yticks([0, .005, .01, .015])
    ax.set_xlim(0, windows[-1, -1])

# %%
def plot_gmin(windows, d, title=None, ax=None):
    
    # set up figure
    if ax is None:
        fig, ax = subplots(figsize=(8, 1.5))
    if title is not None:
        ax.set_title(title, fontweight='bold')

    # window centres
    x = np.array(windows).mean(axis=1)

    # Gmin
    y = d.min(axis=1) / d.mean(axis=1)
    ax.plot(x, y, color='k', lw=1, linestyle='-')
        
    # tidy up
    ax.set_ylabel(r'$G_{min}$', rotation=0, ha='right', va='center')
    ax.set_xlim(0, windows[-1, -1])
    ax.set_ylim(0, 1)
    ax.set_yticks([0, 1])

# %%
autosomes = ['3L', '3R']

# %%
def run_2pop_analysis(pop1, pop2):
    for chrom in autosomes:
        fig = plt.figure(figsize=(13, 11))
        windows, dw1, dw2, db = extract_2pop_dscan(chrom, pop1, pop2)
        
        ax = fig.add_subplot(4, 1, 1)
        sns.despine(ax=ax, bottom=True, offset=5)
        plot_dist_scan(windows, dw1, title='%s, %s' % (pop1, chrom), color=palette[0], ax=ax)
        ax.set_xticks([])
        ax.set_ylabel(r'$\pi$', rotation=0, ha='right', va='center')
        
        ax = fig.add_subplot(4, 1, 2)
        sns.despine(ax=ax, bottom=True, offset=5)
        plot_dist_scan(windows, dw2, title='%s, %s' % (pop2, chrom), color=palette[1], ax=ax)
        ax.set_xticks([])
        ax.set_ylabel(r'$\pi$', rotation=0, ha='right', va='center')
        
        ax = fig.add_subplot(4, 1, 3)
        sns.despine(ax=ax, bottom=True, offset=5)
        plot_dist_scan(windows, db, title='%s/%s, %s' % (pop1, pop2, chrom), color=palette[2], ax=ax)
        ax.set_xticks([])
        ax.set_ylabel(r'$d_{XY}$', rotation=0, ha='right', va='center')

        ax = fig.add_subplot(4, 1, 4)
        sns.despine(ax=ax, offset=5)
        plot_gmin(windows, db, title='%s/%s, %s' % (pop1, pop2, chrom), ax=ax)
        ax.set_xlabel('position (bp)')
        
        fig.tight_layout()
        plt.show()

# %%
run_2pop_analysis('KE', 'BFcol')
# Out:
# 748 windows
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b83d69049238> in <module>
# ----> 1 run_2pop_analysis('KE', 'BFcol')
#
# <ipython-input-42-48aca3132276> in run_2pop_analysis(pop1, pop2)
#       2     for chrom in autosomes:
#       3         fig = plt.figure(figsize=(13, 11))
# ----> 4         windows, dw1, dw2, db = extract_2pop_dscan(chrom, pop1, pop2)
#       5
#       6         ax = fig.add_subplot(4, 1, 1)
#
# <ipython-input-38-89fccf42b578> in extract_2pop_dscan(chrom, pop1, pop2)
#      17
#      18     # locate indices of pairwise comparisons within and between populations
# ---> 19     dw1_ix = allel.condensed_coords_within(pop1_haplotype_indices, n_haplotypes)
#      20     dw2_ix = allel.condensed_coords_within(pop2_haplotype_indices, n_haplotypes)
#      21     db_ix = allel.condensed_coords_between(pop1_haplotype_indices, pop2_haplotype_indices, n_haplotypes)
#
# E:\Programmi\Miniconda\envs\pyenv1\lib\site-packages\allel\stats\distance.py in condensed_coords_within(pop, n)
#     307
#     308     return [condensed_coords(i, j, n)
# --> 309             for i, j in itertools.combinations(sorted(pop), 2)]
#     310
#     311
#
# E:\Programmi\Miniconda\envs\pyenv1\lib\site-packages\allel\stats\distance.py in <listcomp>(.0)
#     307
#     308     return [condensed_coords(i, j, n)
# --> 309             for i, j in itertools.combinations(sorted(pop), 2)]
#     310
#     311
#
# E:\Programmi\Miniconda\envs\pyenv1\lib\site-packages\allel\stats\distance.py in condensed_coords(i, j, n)
#     274     # guard conditions
#     275     if i == j or i >= n or j >= n or i < 0 or j < 0:
# --> 276         raise ValueError('invalid coordinates: %s, %s' % (i, j))
#     277
#     278     # normalise order
#
# ValueError: invalid coordinates: 1004, 1005

# %%
run_2pop_analysis('KE', 'AOcol')
