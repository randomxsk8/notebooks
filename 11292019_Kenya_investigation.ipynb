# %% [markdown]
# # Kenya investigation
# On this notebook i performed ABBA-BABA test to check the tree concordance with Kenya and explored regions where gene flow has occour:

# %%
Image(filename=r'D:\Drive\Dropbox\Ag1000G_carlo\notebooks\images\treemix\Chromosome_3_tree_only.png')

# %%
import allel
import zarr
import pandas as pd
import petl as etl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
palette = sns.color_palette()

# %%
calldata_out= zarr.open('D:/Genomes/extras/outgroup_alleles_phase2.zarr')
calldata_out.tree()
# Out:
# /
#  ├── 2L
#  │   ├── arab (8906423, 2) int32
#  │   ├── chri (8906423, 2) int32
#  │   ├── epir (8906423, 2) int32
#  │   ├── mela (8906423, 2) int32
#  │   ├── meru (8906423, 2) int32
#  │   └── quad (8906423, 2) int32
#  ├── 2R
#  │   ├── arab (12047846, 2) int32
#  │   ├── chri (12047846, 2) int32
#  │   ├── epir (12047846, 2) int32
#  │   ├── mela (12047846, 2) int32
#  │   ├── meru (12047846, 2) int32
#  │   └── quad (12047846, 2) int32
#  ├── 3L
#  │   ├── arab (7897666, 2) int32
#  │   ├── chri (7897666, 2) int32
#  │   ├── epir (7897666, 2) int32
#  │   ├── mela (7897666, 2) int32
#  │   ├── meru (7897666, 2) int32
#  │   └── quad (7897666, 2) int32
#  ├── 3R
#  │   ├── arab (10752701, 2) int32
#  │   ├── chri (10752701, 2) int32
#  │   ├── epir (10752701, 2) int32
#  │   ├── mela (10752701, 2) int32
#  │   ├── meru (10752701, 2) int32
#  │   └── quad (10752701, 2) int32
#  └── X
#      ├── arab (4472265, 2) int32
#      ├── chri (4472265, 2) int32
#      ├── epir (4472265, 2) int32
#      ├── mela (4472265, 2) int32
#      ├── meru (4472265, 2) int32
#      └── quad (4472265, 2) int32

# %%
calldata_biallel= zarr.open('D:/Genomes/extras/phase2_biallel_allele_count.zarr')
calldata_biallel.tree()
# Out:
# /
#  ├── 2L
#  │   ├── AOcol (8906423, 2) int32
#  │   ├── BFcol (8906423, 2) int32
#  │   ├── BFgam (8906423, 2) int32
#  │   ├── CIcol (8906423, 2) int32
#  │   ├── CMgam (8906423, 2) int32
#  │   ├── FRgam (8906423, 2) int32
#  │   ├── GAgam (8906423, 2) int32
#  │   ├── GHcol (8906423, 2) int32
#  │   ├── GHgam (8906423, 2) int32
#  │   ├── GM (8906423, 2) int32
#  │   ├── GNcol (8906423, 2) int32
#  │   ├── GNgam (8906423, 2) int32
#  │   ├── GQgam (8906423, 2) int32
#  │   ├── GW (8906423, 2) int32
#  │   ├── KE (8906423, 2) int32
#  │   └── UGgam (8906423, 2) int32
#  ├── 2R
#  │   ├── AOcol (12047846, 2) int32
#  │   ├── BFcol (12047846, 2) int32
#  │   ├── BFgam (12047846, 2) int32
#  │   ├── CIcol (12047846, 2) int32
#  │   ├── CMgam (12047846, 2) int32
#  │   ├── FRgam (12047846, 2) int32
#  │   ├── GAgam (12047846, 2) int32
#  │   ├── GHcol (12047846, 2) int32
#  │   ├── GHgam (12047846, 2) int32
#  │   ├── GM (12047846, 2) int32
#  │   ├── GNcol (12047846, 2) int32
#  │   ├── GNgam (12047846, 2) int32
#  │   ├── GQgam (12047846, 2) int32
#  │   ├── GW (12047846, 2) int32
#  │   ├── KE (12047846, 2) int32
#  │   └── UGgam (12047846, 2) int32
#  ├── 3L
#  │   ├── AOcol (7897666, 2) int32
#  │   ├── BFcol (7897666, 2) int32
#  │   ├── BFgam (7897666, 2) int32
#  │   ├── CIcol (7897666, 2) int32
#  │   ├── CMgam (7897666, 2) int32
#  │   ├── FRgam (7897666, 2) int32
#  │   ├── GAgam (7897666, 2) int32
#  │   ├── GHcol (7897666, 2) int32
#  │   ├── GHgam (7897666, 2) int32
#  │   ├── GM (7897666, 2) int32
#  │   ├── GNcol (7897666, 2) int32
#  │   ├── GNgam (7897666, 2) int32
#  │   ├── GQgam (7897666, 2) int32
#  │   ├── GW (7897666, 2) int32
#  │   ├── KE (7897666, 2) int32
#  │   └── UGgam (7897666, 2) int32
#  ├── 3R
#  │   ├── AOcol (10752701, 2) int32
#  │   ├── BFcol (10752701, 2) int32
#  │   ├── BFgam (10752701, 2) int32
#  │   ├── CIcol (10752701, 2) int32
#  │   ├── CMgam (10752701, 2) int32
#  │   ├── FRgam (10752701, 2) int32
#  │   ├── GAgam (10752701, 2) int32
#  │   ├── GHcol (10752701, 2) int32
#  │   ├── GHgam (10752701, 2) int32
#  │   ├── GM (10752701, 2) int32
#  │   ├── GNcol (10752701, 2) int32
#  │   ├── GNgam (10752701, 2) int32
#  │   ├── GQgam (10752701, 2) int32
#  │   ├── GW (10752701, 2) int32
#  │   ├── KE (10752701, 2) int32
#  │   └── UGgam (10752701, 2) int32
#  └── X
#      ├── AOcol (4472265, 2) int32
#      ├── BFcol (4472265, 2) int32
#      ├── BFgam (4472265, 2) int32
#      ├── CIcol (4472265, 2) int32
#      ├── CMgam (4472265, 2) int32
#      ├── FRgam (4472265, 2) int32
#      ├── GAgam (4472265, 2) int32
#      ├── GHcol (4472265, 2) int32
#      ├── GHgam (4472265, 2) int32
#      ├── GM (4472265, 2) int32
#      ├── GNcol (4472265, 2) int32
#      ├── GNgam (4472265, 2) int32
#      ├── GQgam (4472265, 2) int32
#      ├── GW (4472265, 2) int32
#      ├── KE (4472265, 2) int32
#      └── UGgam (4472265, 2) int32

# %%
callset_biallel = zarr.open('D:/Genomes/variation/ag1000g.phase2.ar1.pass.biallelic')
callset_biallel.tree()
# Out:
# /
#  ├── 2L
#  │   ├── samples (1142,) object
#  │   └── variants
#  │       ├── ABHet (8906423,) float32
#  │       ├── ABHom (8906423,) float32
#  │       ├── AC (8906423,) int32
#  │       ├── AF (8906423,) float32
#  │       ├── ALT (8906423,) |S1
#  │       ├── AN (8906423,) int32
#  │       ├── Accessible (8906423,) bool
#  │       ├── BaseCounts (8906423, 4) int32
#  │       ├── BaseQRankSum (8906423,) float32
#  │       ├── Coverage (8906423,) int32
#  │       ├── CoverageMQ0 (8906423,) int32
#  │       ├── DP (8906423,) int32
#  │       ├── DS (8906423,) bool
#  │       ├── Dels (8906423,) float32
#  │       ├── FILTER_BaseQRankSum (8906423,) bool
#  │       ├── FILTER_FS (8906423,) bool
#  │       ├── FILTER_HRun (8906423,) bool
#  │       ├── FILTER_HighCoverage (8906423,) bool
#  │       ├── FILTER_HighMQ0 (8906423,) bool
#  │       ├── FILTER_LowCoverage (8906423,) bool
#  │       ├── FILTER_LowMQ (8906423,) bool
#  │       ├── FILTER_LowQual (8906423,) bool
#  │       ├── FILTER_NoCoverage (8906423,) bool
#  │       ├── FILTER_PASS (8906423,) bool
#  │       ├── FILTER_QD (8906423,) bool
#  │       ├── FILTER_ReadPosRankSum (8906423,) bool
#  │       ├── FILTER_RefN (8906423,) bool
#  │       ├── FILTER_RepeatDUST (8906423,) bool
#  │       ├── FS (8906423,) float32
#  │       ├── HRun (8906423,) int32
#  │       ├── HW (8906423,) float32
#  │       ├── HaplotypeScore (8906423,) float32
#  │       ├── HighCoverage (8906423,) int32
#  │       ├── HighMQ0 (8906423,) int32
#  │       ├── InbreedingCoeff (8906423,) float32
#  │       ├── LowCoverage (8906423,) int32
#  │       ├── LowMQ (8906423,) int32
#  │       ├── LowPairing (8906423,) int32
#  │       ├── MLEAC (8906423,) int32
#  │       ├── MLEAF (8906423,) float32
#  │       ├── MQ (8906423,) float32
#  │       ├── MQ0 (8906423,) int32
#  │       ├── MQRankSum (8906423,) float32
#  │       ├── NDA (8906423,) int32
#  │       ├── NoCoverage (8906423,) int32
#  │       ├── OND (8906423,) float32
#  │       ├── POS (8906423,) int32
#  │       ├── QD (8906423,) float32
#  │       ├── QUAL (8906423,) float32
#  │       ├── REF (8906423,) |S1
#  │       ├── RPA (8906423,) int32
#  │       ├── RU (8906423,) object
#  │       ├── ReadPosRankSum (8906423,) float32
#  │       ├── RefMasked (8906423,) bool
#  │       ├── RefN (8906423,) bool
#  │       ├── RepeatDUST (8906423,) bool
#  │       ├── RepeatMasker (8906423,) bool
#  │       ├── RepeatTRF (8906423,) bool
#  │       ├── STR (8906423,) bool
#  │       ├── VariantType (8906423,) object
#  │       ├── altlen (8906423,) int32
#  │       ├── is_snp (8906423,) bool
#  │       └── numalt (8906423,) int32
#  ├── 2R
#  │   ├── samples (1142,) object
#  │   └── variants
#  │       ├── ABHet (12047846,) float32
#  │       ├── ABHom (12047846,) float32
#  │       ├── AC (12047846,) int32
#  │       ├── AF (12047846,) float32
#  │       ├── ALT (12047846,) |S1
#  │       ├── AN (12047846,) int32
#  │       ├── Accessible (12047846,) bool
#  │       ├── BaseCounts (12047846, 4) int32
#  │       ├── BaseQRankSum (12047846,) float32
#  │       ├── Coverage (12047846,) int32
#  │       ├── CoverageMQ0 (12047846,) int32
#  │       ├── DP (12047846,) int32
#  │       ├── DS (12047846,) bool
#  │       ├── Dels (12047846,) float32
#  │       ├── FILTER_BaseQRankSum (12047846,) bool
#  │       ├── FILTER_FS (12047846,) bool
#  │       ├── FILTER_HRun (12047846,) bool
#  │       ├── FILTER_HighCoverage (12047846,) bool
#  │       ├── FILTER_HighMQ0 (12047846,) bool
#  │       ├── FILTER_LowCoverage (12047846,) bool
#  │       ├── FILTER_LowMQ (12047846,) bool
#  │       ├── FILTER_LowQual (12047846,) bool
#  │       ├── FILTER_NoCoverage (12047846,) bool
#  │       ├── FILTER_PASS (12047846,) bool
#  │       ├── FILTER_QD (12047846,) bool
#  │       ├── FILTER_ReadPosRankSum (12047846,) bool
#  │       ├── FILTER_RefN (12047846,) bool
#  │       ├── FILTER_RepeatDUST (12047846,) bool
#  │       ├── FS (12047846,) float32
#  │       ├── HRun (12047846,) int32
#  │       ├── HW (12047846,) float32
#  │       ├── HaplotypeScore (12047846,) float32
#  │       ├── HighCoverage (12047846,) int32
#  │       ├── HighMQ0 (12047846,) int32
#  │       ├── InbreedingCoeff (12047846,) float32
#  │       ├── LowCoverage (12047846,) int32
#  │       ├── LowMQ (12047846,) int32
#  │       ├── LowPairing (12047846,) int32
#  │       ├── MLEAC (12047846,) int32
#  │       ├── MLEAF (12047846,) float32
#  │       ├── MQ (12047846,) float32
#  │       ├── MQ0 (12047846,) int32
#  │       ├── MQRankSum (12047846,) float32
#  │       ├── NDA (12047846,) int32
#  │       ├── NoCoverage (12047846,) int32
#  │       ├── OND (12047846,) float32
#  │       ├── POS (12047846,) int32
#  │       ├── QD (12047846,) float32
#  │       ├── QUAL (12047846,) float32
#  │       ├── REF (12047846,) |S1
#  │       ├── RPA (12047846,) int32
#  │       ├── RU (12047846,) object
#  │       ├── ReadPosRankSum (12047846,) float32
#  │       ├── RefMasked (12047846,) bool
#  │       ├── RefN (12047846,) bool
#  │       ├── RepeatDUST (12047846,) bool
#  │       ├── RepeatMasker (12047846,) bool
#  │       ├── RepeatTRF (12047846,) bool
#  │       ├── STR (12047846,) bool
#  │       ├── VariantType (12047846,) object
#  │       ├── altlen (12047846,) int32
#  │       ├── is_snp (12047846,) bool
#  │       └── numalt (12047846,) int32
#  ├── 3L
#  │   ├── samples (1142,) object
#  │   └── variants
#  │       ├── ABHet (7897666,) float32
#  │       ├── ABHom (7897666,) float32
#  │       ├── AC (7897666,) int32
#  │       ├── AF (7897666,) float32
#  │       ├── ALT (7897666,) |S1
#  │       ├── AN (7897666,) int32
#  │       ├── Accessible (7897666,) bool
#  │       ├── BaseCounts (7897666, 4) int32
#  │       ├── BaseQRankSum (7897666,) float32
#  │       ├── Coverage (7897666,) int32
#  │       ├── CoverageMQ0 (7897666,) int32
#  │       ├── DP (7897666,) int32
#  │       ├── DS (7897666,) bool
#  │       ├── Dels (7897666,) float32
#  │       ├── FILTER_BaseQRankSum (7897666,) bool
#  │       ├── FILTER_FS (7897666,) bool
#  │       ├── FILTER_HRun (7897666,) bool
#  │       ├── FILTER_HighCoverage (7897666,) bool
#  │       ├── FILTER_HighMQ0 (7897666,) bool
#  │       ├── FILTER_LowCoverage (7897666,) bool
#  │       ├── FILTER_LowMQ (7897666,) bool
#  │       ├── FILTER_LowQual (7897666,) bool
#  │       ├── FILTER_NoCoverage (7897666,) bool
#  │       ├── FILTER_PASS (7897666,) bool
#  │       ├── FILTER_QD (7897666,) bool
#  │       ├── FILTER_ReadPosRankSum (7897666,) bool
#  │       ├── FILTER_RefN (7897666,) bool
#  │       ├── FILTER_RepeatDUST (7897666,) bool
#  │       ├── FS (7897666,) float32
#  │       ├── HRun (7897666,) int32
#  │       ├── HW (7897666,) float32
#  │       ├── HaplotypeScore (7897666,) float32
#  │       ├── HighCoverage (7897666,) int32
#  │       ├── HighMQ0 (7897666,) int32
#  │       ├── InbreedingCoeff (7897666,) float32
#  │       ├── LowCoverage (7897666,) int32
#  │       ├── LowMQ (7897666,) int32
#  │       ├── LowPairing (7897666,) int32
#  │       ├── MLEAC (7897666,) int32
#  │       ├── MLEAF (7897666,) float32
#  │       ├── MQ (7897666,) float32
#  │       ├── MQ0 (7897666,) int32
#  │       ├── MQRankSum (7897666,) float32
#  │       ├── NDA (7897666,) int32
#  │       ├── NoCoverage (7897666,) int32
#  │       ├── OND (7897666,) float32
#  │       ├── POS (7897666,) int32
#  │       ├── QD (7897666,) float32
#  │       ├── QUAL (7897666,) float32
#  │       ├── REF (7897666,) |S1
#  │       ├── RPA (7897666,) int32
#  │       ├── RU (7897666,) object
#  │       ├── ReadPosRankSum (7897666,) float32
#  │       ├── RefMasked (7897666,) bool
#  │       ├── RefN (7897666,) bool
#  │       ├── RepeatDUST (7897666,) bool
#  │       ├── RepeatMasker (7897666,) bool
#  │       ├── RepeatTRF (7897666,) bool
#  │       ├── STR (7897666,) bool
#  │       ├── VariantType (7897666,) object
#  │       ├── altlen (7897666,) int32
#  │       ├── is_snp (7897666,) bool
#  │       └── numalt (7897666,) int32
#  ├── 3R
#  │   ├── samples (1142,) object
#  │   └── variants
#  │       ├── ABHet (10752701,) float32
#  │       ├── ABHom (10752701,) float32
#  │       ├── AC (10752701,) int32
#  │       ├── AF (10752701,) float32
#  │       ├── ALT (10752701,) |S1
#  │       ├── AN (10752701,) int32
#  │       ├── Accessible (10752701,) bool
#  │       ├── BaseCounts (10752701, 4) int32
#  │       ├── BaseQRankSum (10752701,) float32
#  │       ├── Coverage (10752701,) int32
#  │       ├── CoverageMQ0 (10752701,) int32
#  │       ├── DP (10752701,) int32
#  │       ├── DS (10752701,) bool
#  │       ├── Dels (10752701,) float32
#  │       ├── FILTER_BaseQRankSum (10752701,) bool
#  │       ├── FILTER_FS (10752701,) bool
#  │       ├── FILTER_HRun (10752701,) bool
#  │       ├── FILTER_HighCoverage (10752701,) bool
#  │       ├── FILTER_HighMQ0 (10752701,) bool
#  │       ├── FILTER_LowCoverage (10752701,) bool
#  │       ├── FILTER_LowMQ (10752701,) bool
#  │       ├── FILTER_LowQual (10752701,) bool
#  │       ├── FILTER_NoCoverage (10752701,) bool
#  │       ├── FILTER_PASS (10752701,) bool
#  │       ├── FILTER_QD (10752701,) bool
#  │       ├── FILTER_ReadPosRankSum (10752701,) bool
#  │       ├── FILTER_RefN (10752701,) bool
#  │       ├── FILTER_RepeatDUST (10752701,) bool
#  │       ├── FS (10752701,) float32
#  │       ├── HRun (10752701,) int32
#  │       ├── HW (10752701,) float32
#  │       ├── HaplotypeScore (10752701,) float32
#  │       ├── HighCoverage (10752701,) int32
#  │       ├── HighMQ0 (10752701,) int32
#  │       ├── InbreedingCoeff (10752701,) float32
#  │       ├── LowCoverage (10752701,) int32
#  │       ├── LowMQ (10752701,) int32
#  │       ├── LowPairing (10752701,) int32
#  │       ├── MLEAC (10752701,) int32
#  │       ├── MLEAF (10752701,) float32
#  │       ├── MQ (10752701,) float32
#  │       ├── MQ0 (10752701,) int32
#  │       ├── MQRankSum (10752701,) float32
#  │       ├── NDA (10752701,) int32
#  │       ├── NoCoverage (10752701,) int32
#  │       ├── OND (10752701,) float32
#  │       ├── POS (10752701,) int32
#  │       ├── QD (10752701,) float32
#  │       ├── QUAL (10752701,) float32
#  │       ├── REF (10752701,) |S1
#  │       ├── RPA (10752701,) int32
#  │       ├── RU (10752701,) object
#  │       ├── ReadPosRankSum (10752701,) float32
#  │       ├── RefMasked (10752701,) bool
#  │       ├── RefN (10752701,) bool
#  │       ├── RepeatDUST (10752701,) bool
#  │       ├── RepeatMasker (10752701,) bool
#  │       ├── RepeatTRF (10752701,) bool
#  │       ├── STR (10752701,) bool
#  │       ├── VariantType (10752701,) object
#  │       ├── altlen (10752701,) int32
#  │       ├── is_snp (10752701,) bool
#  │       └── numalt (10752701,) int32
#  └── X
#      ├── samples (1142,) object
#      └── variants
#          ├── ABHet (4472265,) float32
#          ├── ABHom (4472265,) float32
#          ├── AC (4472265,) int32
#          ├── AF (4472265,) float32
#          ├── ALT (4472265,) |S1
#          ├── AN (4472265,) int32
#          ├── Accessible (4472265,) bool
#          ├── BaseCounts (4472265, 4) int32
#          ├── BaseQRankSum (4472265,) float32
#          ├── Coverage (4472265,) int32
#          ├── CoverageMQ0 (4472265,) int32
#          ├── DP (4472265,) int32
#          ├── DS (4472265,) bool
#          ├── Dels (4472265,) float32
#          ├── FILTER_BaseQRankSum (4472265,) bool
#          ├── FILTER_FS (4472265,) bool
#          ├── FILTER_HRun (4472265,) bool
#          ├── FILTER_HighCoverage (4472265,) bool
#          ├── FILTER_HighMQ0 (4472265,) bool
#          ├── FILTER_LowCoverage (4472265,) bool
#          ├── FILTER_LowMQ (4472265,) bool
#          ├── FILTER_LowQual (4472265,) bool
#          ├── FILTER_NoCoverage (4472265,) bool
#          ├── FILTER_PASS (4472265,) bool
#          ├── FILTER_QD (4472265,) bool
#          ├── FILTER_ReadPosRankSum (4472265,) bool
#          ├── FILTER_RefN (4472265,) bool
#          ├── FILTER_RepeatDUST (4472265,) bool
#          ├── FS (4472265,) float32
#          ├── HRun (4472265,) int32
#          ├── HW (4472265,) float32
#          ├── HaplotypeScore (4472265,) float32
#          ├── HighCoverage (4472265,) int32
#          ├── HighMQ0 (4472265,) int32
#          ├── InbreedingCoeff (4472265,) float32
#          ├── LowCoverage (4472265,) int32
#          ├── LowMQ (4472265,) int32
#          ├── LowPairing (4472265,) int32
#          ├── MLEAC (4472265,) int32
#          ├── MLEAF (4472265,) float32
#          ├── MQ (4472265,) float32
#          ├── MQ0 (4472265,) int32
#          ├── MQRankSum (4472265,) float32
#          ├── NDA (4472265,) int32
#          ├── NoCoverage (4472265,) int32
#          ├── OND (4472265,) float32
#          ├── POS (4472265,) int32
#          ├── QD (4472265,) float32
#          ├── QUAL (4472265,) float32
#          ├── REF (4472265,) |S1
#          ├── RPA (4472265,) int32
#          ├── RU (4472265,) object
#          ├── ReadPosRankSum (4472265,) float32
#          ├── RefMasked (4472265,) bool
#          ├── RefN (4472265,) bool
#          ├── RepeatDUST (4472265,) bool
#          ├── RepeatMasker (4472265,) bool
#          ├── RepeatTRF (4472265,) bool
#          ├── STR (4472265,) bool
#          ├── VariantType (4472265,) object
#          ├── altlen (4472265,) int32
#          ├── is_snp (4472265,) bool
#          └── numalt (4472265,) int32

# %%
an_col = 'AOcol', 'BFcol', 'GNcol', 'CIcol', 'GHcol'
an_gam = 'GHgam', 'CMgam', 'BFgam', 'GNgam', 'GQgam', 'UGgam', 'GAgam', 'FRgam'
an_na = 'KE', 'GM', 'GW'
out_species = ['arab', 'chri', 'epir', 'mela', 'meru', 'quad']

# %%
chromosomes = ['3L', '3R']

# %%
ac_cache = dict()

def load_ac(chrom, pop):
    if (chrom, pop) in ac_cache:
        return ac_cache[chrom, pop]
    else:
        if pop in out_species:
            ac = calldata_out[chrom][pop]
        else:
            ac = calldata_biallel[chrom][pop]
            ac_cache[chrom, pop] = ac
        return ac
    
fourpop_cache = dict()

# %%
def f4_analysis(chroms, A, B, C, D, regions=None, blen=100000, plot=False, ax=None):
    
    
    
    region_str = ",".join(["{0}_{1}".format(r.start, r.stop) for r in regions])
    
    key = (",".join(chroms), region_str, A, B, C, D, blen)
    if key in fourpop_cache:
        # re-use from cache
        d, d_se, d_z, d_vb, d_vj = fourpop_cache[key]
        
    else:
        # load allele counts
        aca = np.vstack([load_ac(chrom, A)[region] for chrom, region in zip(chroms, regions)])
        acb = np.vstack([load_ac(chrom, B)[region] for chrom, region in zip(chroms, regions)])
        acc = np.vstack([load_ac(chrom, C)[region] for chrom, region in zip(chroms, regions)])
        acd = np.vstack([load_ac(chrom, D)[region] for chrom, region in zip(chroms, regions)])
            
        # run D test
        d, d_se, d_z, d_vb, d_vj = allel.blockwise_patterson_d(aca, acb, acc, acd, 
                                                                     blen=blen)
        
        # cache for re-use
        fourpop_cache[key] = d, d_se, d_z, d_vb, d_vj
    
    return d, d_se, d_z, d_vb, d_vj

def f4_analys(As, Bs, Cs, Ds, chroms=chromosomes, regions=None, blen=100000):
    
    if regions is None:
        regions = [slice(None)] * 4
    
    region_str = ",".join(["{0}_{1}".format(r.start, r.stop) for r in regions])
    # normalise inputs
    if not isinstance(chroms, (list, tuple)):
        chroms = [chroms]
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
        
    # setup output table
    tbl = [['chromosome', 'test', 'D', 'SE', 'Z']]

    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, _, _ = f4_analysis(chroms, A, B, C, D, 
                                                             regions=regions, blen=blen)
                            test = 'D(%s, %s; %s, %s)' % (A, B, C, D)
                            row = [",".join(chroms), test, d, d_se, d_z]
                            tbl += [row]

    # display results
    (etl
     .wrap(tbl)
     .interpolate('D', '%.3f')
     .interpolate('SE', '%.4f')
     .interpolate('Z', '%.1f')
     .displayall(index_header=False, 
                 tr_style=lambda row: 'background-color: %s' % ('#afa' if float(row.Z) > 5 else '#aaf' if float(row.Z) < -5 else 'white')))

# %% [markdown]
# -----------------------------
# ## Testing Euchromatic Region of Chromosome 3

# %%
A = an_col
B = an_gam
C = 'KE'
D = 'chri'

# %%
f4_analys(A, B, C, D, chroms=("3L", "3R"),
                regions=(slice(15000000, 41000000), slice(1000000, 37000000)))
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>chromosome</th>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, GHgam; KE, chri)</td>
# <td>0.057</td>
# <td>0.0048</td>
# <td>11.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, CMgam; KE, chri)</td>
# <td>0.058</td>
# <td>0.0053</td>
# <td>11.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, BFgam; KE, chri)</td>
# <td>0.058</td>
# <td>0.0051</td>
# <td>11.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, GNgam; KE, chri)</td>
# <td>0.059</td>
# <td>0.0052</td>
# <td>11.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, GQgam; KE, chri)</td>
# <td>0.052</td>
# <td>0.0052</td>
# <td>9.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, UGgam; KE, chri)</td>
# <td>0.046</td>
# <td>0.0054</td>
# <td>8.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(AOcol, GAgam; KE, chri)</td>
# <td>0.035</td>
# <td>0.0053</td>
# <td>6.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, FRgam; KE, chri)</td>
# <td>-0.032</td>
# <td>0.0075</td>
# <td>-4.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(BFcol, GHgam; KE, chri)</td>
# <td>0.043</td>
# <td>0.0063</td>
# <td>6.8</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(BFcol, CMgam; KE, chri)</td>
# <td>0.044</td>
# <td>0.0069</td>
# <td>6.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(BFcol, BFgam; KE, chri)</td>
# <td>0.044</td>
# <td>0.0067</td>
# <td>6.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(BFcol, GNgam; KE, chri)</td>
# <td>0.045</td>
# <td>0.0067</td>
# <td>6.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(BFcol, GQgam; KE, chri)</td>
# <td>0.037</td>
# <td>0.0067</td>
# <td>5.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, UGgam; KE, chri)</td>
# <td>0.032</td>
# <td>0.0070</td>
# <td>4.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, GAgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0072</td>
# <td>2.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, FRgam; KE, chri)</td>
# <td>-0.045</td>
# <td>0.0093</td>
# <td>-4.8</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GNcol, GHgam; KE, chri)</td>
# <td>0.030</td>
# <td>0.0056</td>
# <td>5.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GNcol, CMgam; KE, chri)</td>
# <td>0.031</td>
# <td>0.0061</td>
# <td>5.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GNcol, BFgam; KE, chri)</td>
# <td>0.031</td>
# <td>0.0060</td>
# <td>5.2</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GNcol, GNgam; KE, chri)</td>
# <td>0.032</td>
# <td>0.0061</td>
# <td>5.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GQgam; KE, chri)</td>
# <td>0.025</td>
# <td>0.0060</td>
# <td>4.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, UGgam; KE, chri)</td>
# <td>0.020</td>
# <td>0.0062</td>
# <td>3.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GAgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0063</td>
# <td>1.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(GNcol, FRgam; KE, chri)</td>
# <td>-0.056</td>
# <td>0.0085</td>
# <td>-6.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(CIcol, GHgam; KE, chri)</td>
# <td>0.043</td>
# <td>0.0059</td>
# <td>7.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(CIcol, CMgam; KE, chri)</td>
# <td>0.045</td>
# <td>0.0064</td>
# <td>6.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(CIcol, BFgam; KE, chri)</td>
# <td>0.044</td>
# <td>0.0062</td>
# <td>7.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(CIcol, GNgam; KE, chri)</td>
# <td>0.045</td>
# <td>0.0063</td>
# <td>7.2</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(CIcol, GQgam; KE, chri)</td>
# <td>0.038</td>
# <td>0.0063</td>
# <td>6.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, UGgam; KE, chri)</td>
# <td>0.033</td>
# <td>0.0066</td>
# <td>5.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, GAgam; KE, chri)</td>
# <td>0.022</td>
# <td>0.0067</td>
# <td>3.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, FRgam; KE, chri)</td>
# <td>-0.044</td>
# <td>0.0090</td>
# <td>-4.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, GHgam; KE, chri)</td>
# <td>0.048</td>
# <td>0.0064</td>
# <td>7.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, CMgam; KE, chri)</td>
# <td>0.050</td>
# <td>0.0069</td>
# <td>7.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, BFgam; KE, chri)</td>
# <td>0.049</td>
# <td>0.0068</td>
# <td>7.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, GNgam; KE, chri)</td>
# <td>0.050</td>
# <td>0.0068</td>
# <td>7.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, GQgam; KE, chri)</td>
# <td>0.043</td>
# <td>0.0068</td>
# <td>6.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L,3R</td>
# <td>D(GHcol, UGgam; KE, chri)</td>
# <td>0.038</td>
# <td>0.0072</td>
# <td>5.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, GAgam; KE, chri)</td>
# <td>0.027</td>
# <td>0.0072</td>
# <td>3.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, FRgam; KE, chri)</td>
# <td>-0.039</td>
# <td>0.0094</td>
# <td>-4.1</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# -------------------
# ## Testing Heterochromatic Region of Chromosome 3

# %%
A = an_col
B = an_gam
C = 'KE'
D = 'chri'

# %%
f4_analys(A, B, C, D, chroms=("3L", "3R"),
                regions=(slice(1, 15000000), slice(37000000 , 53200684)))
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>chromosome</th>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, GHgam; KE, chri)</td>
# <td>0.017</td>
# <td>0.0044</td>
# <td>3.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, CMgam; KE, chri)</td>
# <td>0.018</td>
# <td>0.0043</td>
# <td>4.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, BFgam; KE, chri)</td>
# <td>0.019</td>
# <td>0.0043</td>
# <td>4.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, GNgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0042</td>
# <td>4.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, GQgam; KE, chri)</td>
# <td>0.014</td>
# <td>0.0040</td>
# <td>3.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, UGgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0048</td>
# <td>1.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(AOcol, GAgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0037</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(AOcol, FRgam; KE, chri)</td>
# <td>-0.054</td>
# <td>0.0064</td>
# <td>-8.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, GHgam; KE, chri)</td>
# <td>0.002</td>
# <td>0.0042</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, CMgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0046</td>
# <td>0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, BFgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0044</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, GNgam; KE, chri)</td>
# <td>0.006</td>
# <td>0.0044</td>
# <td>1.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, GQgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0046</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, UGgam; KE, chri)</td>
# <td>-0.007</td>
# <td>0.0055</td>
# <td>-1.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(BFcol, GAgam; KE, chri)</td>
# <td>-0.012</td>
# <td>0.0048</td>
# <td>-2.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(BFcol, FRgam; KE, chri)</td>
# <td>-0.068</td>
# <td>0.0071</td>
# <td>-9.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GHgam; KE, chri)</td>
# <td>-0.007</td>
# <td>0.0053</td>
# <td>-1.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, CMgam; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0056</td>
# <td>-1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, BFgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0055</td>
# <td>-0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GNgam; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0054</td>
# <td>-0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GQgam; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0055</td>
# <td>-1.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, UGgam; KE, chri)</td>
# <td>-0.015</td>
# <td>0.0065</td>
# <td>-2.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GNcol, GAgam; KE, chri)</td>
# <td>-0.020</td>
# <td>0.0056</td>
# <td>-3.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(GNcol, FRgam; KE, chri)</td>
# <td>-0.076</td>
# <td>0.0080</td>
# <td>-9.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, GHgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0045</td>
# <td>0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, CMgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0049</td>
# <td>0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, BFgam; KE, chri)</td>
# <td>0.005</td>
# <td>0.0047</td>
# <td>1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, GNgam; KE, chri)</td>
# <td>0.007</td>
# <td>0.0047</td>
# <td>1.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, GQgam; KE, chri)</td>
# <td>0.000</td>
# <td>0.0048</td>
# <td>0.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, UGgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0058</td>
# <td>-0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(CIcol, GAgam; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0049</td>
# <td>-2.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(CIcol, FRgam; KE, chri)</td>
# <td>-0.066</td>
# <td>0.0074</td>
# <td>-8.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, GHgam; KE, chri)</td>
# <td>0.007</td>
# <td>0.0047</td>
# <td>1.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, CMgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0051</td>
# <td>1.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, BFgam; KE, chri)</td>
# <td>0.009</td>
# <td>0.0049</td>
# <td>1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, GNgam; KE, chri)</td>
# <td>0.011</td>
# <td>0.0049</td>
# <td>2.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, GQgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0051</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, UGgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0061</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L,3R</td>
# <td>D(GHcol, GAgam; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0052</td>
# <td>-1.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L,3R</td>
# <td>D(GHcol, FRgam; KE, chri)</td>
# <td>-0.062</td>
# <td>0.0076</td>
# <td>-8.1</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# No tree concordance...

# %% [markdown]
# -----------------------------------
# ## Testing 3L

# %%
A = an_col
B = an_gam
C = 'KE'
D = 'chri'

# %%
f4_analys(A, B, C, D, chroms=("3L"))
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>chromosome</th>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, GHgam; KE, chri)</td>
# <td>0.017</td>
# <td>0.0044</td>
# <td>3.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, CMgam; KE, chri)</td>
# <td>0.018</td>
# <td>0.0043</td>
# <td>4.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, BFgam; KE, chri)</td>
# <td>0.019</td>
# <td>0.0043</td>
# <td>4.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, GNgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0042</td>
# <td>4.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, GQgam; KE, chri)</td>
# <td>0.014</td>
# <td>0.0040</td>
# <td>3.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, UGgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0048</td>
# <td>1.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(AOcol, GAgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0037</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L</td>
# <td>D(AOcol, FRgam; KE, chri)</td>
# <td>-0.054</td>
# <td>0.0064</td>
# <td>-8.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, GHgam; KE, chri)</td>
# <td>0.002</td>
# <td>0.0042</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, CMgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0046</td>
# <td>0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, BFgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0044</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, GNgam; KE, chri)</td>
# <td>0.006</td>
# <td>0.0044</td>
# <td>1.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, GQgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0046</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, UGgam; KE, chri)</td>
# <td>-0.007</td>
# <td>0.0055</td>
# <td>-1.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(BFcol, GAgam; KE, chri)</td>
# <td>-0.012</td>
# <td>0.0048</td>
# <td>-2.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L</td>
# <td>D(BFcol, FRgam; KE, chri)</td>
# <td>-0.068</td>
# <td>0.0071</td>
# <td>-9.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, GHgam; KE, chri)</td>
# <td>-0.007</td>
# <td>0.0053</td>
# <td>-1.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, CMgam; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0056</td>
# <td>-1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, BFgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0055</td>
# <td>-0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, GNgam; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0054</td>
# <td>-0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, GQgam; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0055</td>
# <td>-1.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, UGgam; KE, chri)</td>
# <td>-0.015</td>
# <td>0.0065</td>
# <td>-2.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GNcol, GAgam; KE, chri)</td>
# <td>-0.020</td>
# <td>0.0056</td>
# <td>-3.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L</td>
# <td>D(GNcol, FRgam; KE, chri)</td>
# <td>-0.076</td>
# <td>0.0080</td>
# <td>-9.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, GHgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0045</td>
# <td>0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, CMgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0049</td>
# <td>0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, BFgam; KE, chri)</td>
# <td>0.005</td>
# <td>0.0047</td>
# <td>1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, GNgam; KE, chri)</td>
# <td>0.007</td>
# <td>0.0047</td>
# <td>1.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, GQgam; KE, chri)</td>
# <td>0.000</td>
# <td>0.0048</td>
# <td>0.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, UGgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0058</td>
# <td>-0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(CIcol, GAgam; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0049</td>
# <td>-2.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L</td>
# <td>D(CIcol, FRgam; KE, chri)</td>
# <td>-0.066</td>
# <td>0.0074</td>
# <td>-8.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, GHgam; KE, chri)</td>
# <td>0.007</td>
# <td>0.0047</td>
# <td>1.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, CMgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0051</td>
# <td>1.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, BFgam; KE, chri)</td>
# <td>0.009</td>
# <td>0.0049</td>
# <td>1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, GNgam; KE, chri)</td>
# <td>0.011</td>
# <td>0.0049</td>
# <td>2.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, GQgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0051</td>
# <td>0.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, UGgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0061</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L</td>
# <td>D(GHcol, GAgam; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0052</td>
# <td>-1.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L</td>
# <td>D(GHcol, FRgam; KE, chri)</td>
# <td>-0.062</td>
# <td>0.0076</td>
# <td>-8.1</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# -----------------
# ## Testing 3R

# %%
A = an_gam
B = 'KE'
C = an_col
D = 'chri'

# %%
f4_analys(A, B, C, D, chroms=("3R"))
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>chromosome</th>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GHgam, KE; AOcol, chri)</td>
# <td>-0.046</td>
# <td>0.0100</td>
# <td>-4.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GHgam, KE; BFcol, chri)</td>
# <td>-0.052</td>
# <td>0.0100</td>
# <td>-5.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GHgam, KE; GNcol, chri)</td>
# <td>-0.051</td>
# <td>0.0095</td>
# <td>-5.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GHgam, KE; CIcol, chri)</td>
# <td>-0.056</td>
# <td>0.0098</td>
# <td>-5.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GHgam, KE; GHcol, chri)</td>
# <td>-0.060</td>
# <td>0.0102</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(CMgam, KE; AOcol, chri)</td>
# <td>-0.049</td>
# <td>0.0104</td>
# <td>-4.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(CMgam, KE; BFcol, chri)</td>
# <td>-0.057</td>
# <td>0.0106</td>
# <td>-5.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(CMgam, KE; GNcol, chri)</td>
# <td>-0.056</td>
# <td>0.0100</td>
# <td>-5.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(CMgam, KE; CIcol, chri)</td>
# <td>-0.061</td>
# <td>0.0103</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(CMgam, KE; GHcol, chri)</td>
# <td>-0.066</td>
# <td>0.0107</td>
# <td>-6.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(BFgam, KE; AOcol, chri)</td>
# <td>-0.047</td>
# <td>0.0103</td>
# <td>-4.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(BFgam, KE; BFcol, chri)</td>
# <td>-0.054</td>
# <td>0.0104</td>
# <td>-5.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(BFgam, KE; GNcol, chri)</td>
# <td>-0.054</td>
# <td>0.0098</td>
# <td>-5.5</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(BFgam, KE; CIcol, chri)</td>
# <td>-0.058</td>
# <td>0.0102</td>
# <td>-5.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(BFgam, KE; GHcol, chri)</td>
# <td>-0.062</td>
# <td>0.0106</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GNgam, KE; AOcol, chri)</td>
# <td>-0.049</td>
# <td>0.0103</td>
# <td>-4.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GNgam, KE; BFcol, chri)</td>
# <td>-0.055</td>
# <td>0.0104</td>
# <td>-5.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GNgam, KE; GNcol, chri)</td>
# <td>-0.054</td>
# <td>0.0098</td>
# <td>-5.5</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GNgam, KE; CIcol, chri)</td>
# <td>-0.059</td>
# <td>0.0102</td>
# <td>-5.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GNgam, KE; GHcol, chri)</td>
# <td>-0.063</td>
# <td>0.0106</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GQgam, KE; AOcol, chri)</td>
# <td>-0.034</td>
# <td>0.0097</td>
# <td>-3.5</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GQgam, KE; BFcol, chri)</td>
# <td>-0.051</td>
# <td>0.0100</td>
# <td>-5.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GQgam, KE; GNcol, chri)</td>
# <td>-0.050</td>
# <td>0.0093</td>
# <td>-5.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GQgam, KE; CIcol, chri)</td>
# <td>-0.055</td>
# <td>0.0097</td>
# <td>-5.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GQgam, KE; GHcol, chri)</td>
# <td>-0.059</td>
# <td>0.0101</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(UGgam, KE; AOcol, chri)</td>
# <td>-0.046</td>
# <td>0.0099</td>
# <td>-4.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(UGgam, KE; BFcol, chri)</td>
# <td>-0.057</td>
# <td>0.0102</td>
# <td>-5.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(UGgam, KE; GNcol, chri)</td>
# <td>-0.056</td>
# <td>0.0096</td>
# <td>-5.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(UGgam, KE; CIcol, chri)</td>
# <td>-0.061</td>
# <td>0.0100</td>
# <td>-6.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(UGgam, KE; GHcol, chri)</td>
# <td>-0.065</td>
# <td>0.0104</td>
# <td>-6.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GAgam, KE; AOcol, chri)</td>
# <td>-0.023</td>
# <td>0.0094</td>
# <td>-2.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GAgam, KE; BFcol, chri)</td>
# <td>-0.044</td>
# <td>0.0098</td>
# <td>-4.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(GAgam, KE; GNcol, chri)</td>
# <td>-0.044</td>
# <td>0.0093</td>
# <td>-4.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GAgam, KE; CIcol, chri)</td>
# <td>-0.049</td>
# <td>0.0096</td>
# <td>-5.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(GAgam, KE; GHcol, chri)</td>
# <td>-0.052</td>
# <td>0.0099</td>
# <td>-5.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R</td>
# <td>D(FRgam, KE; AOcol, chri)</td>
# <td>-0.037</td>
# <td>0.0093</td>
# <td>-4.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(FRgam, KE; BFcol, chri)</td>
# <td>-0.055</td>
# <td>0.0096</td>
# <td>-5.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(FRgam, KE; GNcol, chri)</td>
# <td>-0.055</td>
# <td>0.0091</td>
# <td>-6.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(FRgam, KE; CIcol, chri)</td>
# <td>-0.059</td>
# <td>0.0094</td>
# <td>-6.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R</td>
# <td>D(FRgam, KE; GHcol, chri)</td>
# <td>-0.063</td>
# <td>0.0098</td>
# <td>-6.5</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# -----------------------
# ## Testing 3L-free region

# %%
def count_alleles_pos(chrom, start, stop):
    
    metadata = pd.read_csv("D:/Genomes/meta/samples.meta.txt", sep="\t")
    pos_all = allel.SortedIndex(callset_biallel[chrom]["variants/POS"])
    loc = pos_all.intersect_range(start, stop)
    loc1, loc2 = pos_all.locate_intersection(loc)
    geno = allel.GenotypeChunkedArray(callset_biallel[chrom]["calldata/GT"])
    geno_subset = geno.subset(sel0=loc1)
    ac = geno_subset.count_alleles()[:]
    grp = metadata.groupby("population")
    grp_indices = grp.indices
    ac_subpops = geno_subset.count_alleles_subpops(grp_indices)

    return ac_subpops

# %%
ac_3L_free = count_alleles_pos('3L', 15000000, 41000000)
ac_3L_free
# Out:
# <AlleleCountsChunkedTable shape=(5989818,) dtype=[('AOcol', '<i4', (2,)), ('BFcol', '<i4', (2,)), ('BFgam', '<i4', (2,)), ('CIcol', '<i4', (2,)), ('CMgam', '<i4', (2,)), ('FRgam', '<i4', (2,)), ('GAgam', '<i4', (2,)), ('GHcol', '<i4', (2,)), ('GHgam', '<i4', (2,)), ('GM', '<i4', (2,)), ('GNcol', '<i4', (2,)), ('GNgam', '<i4', (2,)), ('GQgam', '<i4', (2,)), ('GW', '<i4', (2,)), ('KE', '<i4', (2,)), ('UGgam', '<i4', (2,))]
#    nbytes=731.2M cbytes=64.7M cratio=11.3
#    values=allel.chunked.storage_zarr.ZarrTable>

# %%
ac_chri_3L_free = allel.AlleleCountsChunkedArray(calldata_out['3L']['chri']).compress(loc1)
ac_chri_3L_free
# Out:
# <AlleleCountsChunkedArray shape=(5989818, 2) dtype=int32 chunks=(93591, 2)
#    nbytes=45.7M cbytes=4.0M cratio=11.5
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac_cache = dict()

def load_ac(pop):
    if (pop) in ac_cache:
        return ac_cache[pop]
    else:
        if pop in out_species:
            ac = ac_chri_3L_free
        else:
            ac = ac_3L_free[pop]
            ac_cache[pop] = ac
        return ac
    
fourpop_cache = dict()

# %%
#this is the function that perform the test
def f4_analysis(A, B, C, D, blen=100000, plot=False, ax=None):
    
    key = (A, B, C, D, blen)
    if key in fourpop_cache:
        # re-use from cache
        d, d_se, d_z, d_vb, d_vj = fourpop_cache[key]
        
    else:
        # load allele counts
        aca = load_ac(A)
        acb = load_ac(B)
        acc = load_ac(C)
        acd = load_ac(D)

        # run D test
        d, d_se, d_z, d_vb, d_vj = allel.blockwise_patterson_d(aca, acb, acc, acd, blen=blen)
        
        # cache for re-use
        fourpop_cache[key] = d, d_se, d_z, d_vb, d_vj
    
    return d, d_se, d_z, d_vb, d_vj

#this is the function that give me to display multiple tests on a table
def f4_analyses(As, Bs, Cs, Ds, blen=100000):
    
    # normalise inputs
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
        
    # setup output table
    tbl = [['test', 'D', 'SE', 'Z']]
    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, _, _ = f4_analysis(A, B, C, D, blen=blen)
                            test = '3L-free  -  D(%s, %s; %s, %s)' % (A, B, C, D)
                            row = [test, d, d_se, d_z]
                            tbl += [row]
    
    # display results
    (etl
     .wrap(tbl)
     .interpolate('D', '%.3f')
     .interpolate('SE', '%.4f')
     .interpolate('Z', '%.1f')
     .displayall(index_header=False, tr_style=lambda row: 'background-color: %s' % ('#afa' if float(row.Z) > 5 else '#aaf' if float(row.Z) < -5 else 'white')))

# %%
A = an_col
B = an_gam
C = 'KE'
D = 'chri'

# %%
f4_analyses(A, B, C, D)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: #afa'>
# <td>3L-free  -  D(AOcol, GHgam; KE, chri)</td>
# <td>0.029</td>
# <td>0.0034</td>
# <td>8.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free  -  D(AOcol, CMgam; KE, chri)</td>
# <td>0.028</td>
# <td>0.0037</td>
# <td>7.5</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free  -  D(AOcol, BFgam; KE, chri)</td>
# <td>0.030</td>
# <td>0.0037</td>
# <td>8.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free  -  D(AOcol, GNgam; KE, chri)</td>
# <td>0.032</td>
# <td>0.0037</td>
# <td>8.6</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free  -  D(AOcol, GQgam; KE, chri)</td>
# <td>0.022</td>
# <td>0.0042</td>
# <td>5.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(AOcol, UGgam; KE, chri)</td>
# <td>0.018</td>
# <td>0.0044</td>
# <td>4.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(AOcol, GAgam; KE, chri)</td>
# <td>0.010</td>
# <td>0.0041</td>
# <td>2.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free  -  D(AOcol, FRgam; KE, chri)</td>
# <td>-0.046</td>
# <td>0.0079</td>
# <td>-5.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, GHgam; KE, chri)</td>
# <td>0.000</td>
# <td>0.0029</td>
# <td>0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, CMgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0032</td>
# <td>-0.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, BFgam; KE, chri)</td>
# <td>0.001</td>
# <td>0.0032</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, GNgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0032</td>
# <td>0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, GQgam; KE, chri)</td>
# <td>-0.007</td>
# <td>0.0038</td>
# <td>-1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, UGgam; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0039</td>
# <td>-2.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(BFcol, GAgam; KE, chri)</td>
# <td>-0.018</td>
# <td>0.0039</td>
# <td>-4.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free  -  D(BFcol, FRgam; KE, chri)</td>
# <td>-0.072</td>
# <td>0.0081</td>
# <td>-8.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, GHgam; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0050</td>
# <td>-0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, CMgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0054</td>
# <td>-0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, BFgam; KE, chri)</td>
# <td>-0.002</td>
# <td>0.0054</td>
# <td>-0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, GNgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0054</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, GQgam; KE, chri)</td>
# <td>-0.011</td>
# <td>0.0057</td>
# <td>-1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, UGgam; KE, chri)</td>
# <td>-0.014</td>
# <td>0.0060</td>
# <td>-2.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GNcol, GAgam; KE, chri)</td>
# <td>-0.022</td>
# <td>0.0059</td>
# <td>-3.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free  -  D(GNcol, FRgam; KE, chri)</td>
# <td>-0.075</td>
# <td>0.0094</td>
# <td>-8.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, GHgam; KE, chri)</td>
# <td>0.003</td>
# <td>0.0036</td>
# <td>0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, CMgam; KE, chri)</td>
# <td>0.002</td>
# <td>0.0040</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, BFgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0040</td>
# <td>1.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, GNgam; KE, chri)</td>
# <td>0.005</td>
# <td>0.0040</td>
# <td>1.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, GQgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0045</td>
# <td>-1.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, UGgam; KE, chri)</td>
# <td>-0.008</td>
# <td>0.0047</td>
# <td>-1.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(CIcol, GAgam; KE, chri)</td>
# <td>-0.016</td>
# <td>0.0046</td>
# <td>-3.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free  -  D(CIcol, FRgam; KE, chri)</td>
# <td>-0.069</td>
# <td>0.0084</td>
# <td>-8.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, GHgam; KE, chri)</td>
# <td>0.006</td>
# <td>0.0036</td>
# <td>1.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, CMgam; KE, chri)</td>
# <td>0.004</td>
# <td>0.0039</td>
# <td>1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, BFgam; KE, chri)</td>
# <td>0.006</td>
# <td>0.0038</td>
# <td>1.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, GNgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0039</td>
# <td>2.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, GQgam; KE, chri)</td>
# <td>-0.002</td>
# <td>0.0043</td>
# <td>-0.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, UGgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0046</td>
# <td>-1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free  -  D(GHcol, GAgam; KE, chri)</td>
# <td>-0.013</td>
# <td>0.0046</td>
# <td>-2.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free  -  D(GHcol, FRgam; KE, chri)</td>
# <td>-0.067</td>
# <td>0.0084</td>
# <td>-7.9</td>
# </tr>
# </tbody>
# </table>

# %%
def plot_test(As,Bs,Cs,Ds, blen=100000):
    # normalise inputs
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
   
    tbl = []
    tbl2 = [["Block_1","Block_2","Block_3","Block_4","Block_5","Block_6","Block_7","Block_8","Block_9","Block_10","Block_11","Block_12","Block_13","Block_14","Block_15","Block_16","Block_17","Block_18","Block_19","Block_20","Block_21","Block_22","Block_23","Block_24","Block_25","Block_26","Block_27","Block_28","Block_29","Block_30","Block_31","Block_32","Block_33","Block_34","Block_35","Block_36","Block_37","Block_38","Block_39","Block_40","Block_41","Block_42","Block_43","Block_44","Block_45","Block_46","Block_47","Block_48","Block_49","Block_50","Block_51","Block_52","Block_53","Block_54","Block_55","Block_56","Block_57","Block_58","Block_59"]]
    tbl3 = [['Test']]

    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, b1, _ = f4_analysis(A, B, C, D, blen=blen)
                            test = "3L-free - D-Test(%s, %s, %s, %s)" % (A, B, C, D)
                            row = b1
                            tbl += [row]
                            row2 = [test]
                            tbl2 += [row]
                            tbl3 += [row2]
    df1 = etl.todataframe(tbl2)
    df2 = etl.todataframe(tbl3)
    results = df2.join(df1)
    tbl=np.array(tbl)
    #print (tbl)
    fig, ax = plt.subplots(figsize=(14, 4))
    # mean
    pos = callset_biallel['3L']['variants']['POS'][:]
    windows = allel.moving_statistic(loc, statistic=lambda v: [v[0], v[-1]], size=blen)
    x = np.asarray(windows).mean(axis=1)    
    y = np.median(tbl, axis=0)
    plt.plot(x, y, lw=1, label = "median", color=palette[3]) 
    
    #min and max
    y5 = np.max(tbl, axis=0)
    y6 = np.min(tbl, axis=0)
    ax.fill_between(x, y5, y6,label = "min and max", color=palette[9], alpha=.4)
    
    # interquartile range
    y1 = np.percentile(tbl, 25, axis=0)
    y2 = np.percentile(tbl, 75, axis=0)
    ax.fill_between(x, y1, y2, label = "interquartile range", color=palette[2], alpha=.6)
    # 5-95 range
    y3 = np.percentile(tbl, 5, axis=0)
    y4 = np.percentile(tbl, 95, axis=0)
    ax.fill_between(x, y3, y4,label = "5-95 range", color=palette[4], alpha=.4)

    
    ax.set_title(('ABBA BABA Test - Blocks scan (%s bp) on 3L-free') % (blen))
    sns.despine(ax=ax, offset=10)
    ax.set_xlim(loc[0], loc.max())
    ax.set_xlabel('position (bp)')
    #ax.set_ylim(0,0.018)
    sns.despine(ax=ax, offset=10)
    fig.tight_layout()
    # show a legend on the plot 
    plt.legend() 

    # function to show the plot 
    plt.show()
    
    return results, tbl, plt

# %%
results_3L, bloks_3L, plot_3L = plot_test(A,B,C,D, blen = 100000)

# %%
# load variant positions
block_starts = allel.moving_statistic(loc, statistic=np.min, size=100000)
block_stops = allel.moving_statistic(loc, statistic=np.max, size=100000)
block_widths = block_stops - block_starts
title = results_3L['Test']
### qui bisogna fare un ciclo:
for i in range(len(bloks_3L)):	
		ylim=(-.2, .2)
		fig, ax =  plt.subplots(figsize=(14, 6))
		ax.bar(block_starts, bloks_3L[i], width=block_widths, linewidth=0)
		ax.axhline(0, color='k', linestyle='--')
		ax.set_ylabel('D', rotation=0, ha='center', va='center')
		ax.set_ylim(*ylim)
		ax.set_title('%s' %(title[i]))
		sns.despine(ax=ax, offset=10)
		fig.tight_layout()      
i+=1

# %% [markdown]
# --------------------
# ## Testing 3R-free region

# %%
def count_alleles_pos(chrom, start, stop):
    
    metadata = pd.read_csv("D:/Genomes/meta/samples.meta.txt", sep="\t")
    pos_all = allel.SortedIndex(callset_biallel[chrom]["variants/POS"])
    loc = pos_all.intersect_range(start, stop)
    loc1, loc2 = pos_all.locate_intersection(loc)
    geno = allel.GenotypeChunkedArray(callset_biallel[chrom]["calldata/GT"])
    geno_subset = geno.subset(sel0=loc1)
    ac = geno_subset.count_alleles()[:]
    grp = metadata.groupby("population")
    grp_indices = grp.indices
    ac_subpops = geno_subset.count_alleles_subpops(grp_indices)

    return ac_subpops

# %%
ac_3R_free = count_alleles_pos('3R', 1000000, 37000000)
ac_3R_free
# Out:
# <AlleleCountsChunkedTable shape=(8281766,) dtype=[('AOcol', '<i4', (2,)), ('BFcol', '<i4', (2,)), ('BFgam', '<i4', (2,)), ('CIcol', '<i4', (2,)), ('CMgam', '<i4', (2,)), ('FRgam', '<i4', (2,)), ('GAgam', '<i4', (2,)), ('GHcol', '<i4', (2,)), ('GHgam', '<i4', (2,)), ('GM', '<i4', (2,)), ('GNcol', '<i4', (2,)), ('GNgam', '<i4', (2,)), ('GQgam', '<i4', (2,)), ('GW', '<i4', (2,)), ('KE', '<i4', (2,)), ('UGgam', '<i4', (2,))]
#    nbytes=1011.0M cbytes=90.8M cratio=11.1
#    values=allel.chunked.storage_zarr.ZarrTable>

# %%
ac_chri_3R_free = allel.AlleleCountsChunkedArray(calldata_out['3R']['chri']).compress(loc1)
ac_chri_3R_free
# Out:
# <AlleleCountsChunkedArray shape=(8281766, 2) dtype=int32 chunks=(129403, 2)
#    nbytes=63.2M cbytes=5.7M cratio=11.0
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
ac_cache = dict()

def load_ac(pop):
    if (pop) in ac_cache:
        return ac_cache[pop]
    else:
        if pop in out_species:
            ac = ac_chri_3R_free
        else:
            ac = ac_3R_free[pop]
            ac_cache[pop] = ac
        return ac
    
fourpop_cache = dict()

# %%
#this is the function that perform the test
def f4_analysis(A, B, C, D, blen=100000, plot=False, ax=None):
    
    key = (A, B, C, D, blen)
    if key in fourpop_cache:
        # re-use from cache
        d, d_se, d_z, d_vb, d_vj = fourpop_cache[key]
        
    else:
        # load allele counts
        aca = load_ac(A)
        acb = load_ac(B)
        acc = load_ac(C)
        acd = load_ac(D)

        # run D test
        d, d_se, d_z, d_vb, d_vj = allel.blockwise_patterson_d(aca, acb, acc, acd, blen=blen)
        
        # cache for re-use
        fourpop_cache[key] = d, d_se, d_z, d_vb, d_vj
    
    return d, d_se, d_z, d_vb, d_vj

#this is the function that give me to display multiple tests on a table
def f4_analyses(As, Bs, Cs, Ds, blen=100000):
    
    # normalise inputs
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
        
    # setup output table
    tbl = [['test', 'D', 'SE', 'Z']]
    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, _, _ = f4_analysis(A, B, C, D, blen=blen)
                            test = '3R-free - D(%s, %s; %s, %s)' % (A, B, C, D)
                            row = [test, d, d_se, d_z]
                            tbl += [row]
    
    # display results
    (etl
     .wrap(tbl)
     .interpolate('D', '%.3f')
     .interpolate('SE', '%.4f')
     .interpolate('Z', '%.1f')
     .displayall(index_header=False, tr_style=lambda row: 'background-color: %s' % ('#afa' if float(row.Z) > 5 else '#aaf' if float(row.Z) < -5 else 'white')))

# %%
A = an_col
B = an_gam
C = 'KE'
D = 'chri'

# %%
f4_analyses(A, B, C, D)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, GHgam; KE, chri)</td>
# <td>0.046</td>
# <td>0.0043</td>
# <td>10.8</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, CMgam; KE, chri)</td>
# <td>0.045</td>
# <td>0.0042</td>
# <td>10.8</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, BFgam; KE, chri)</td>
# <td>0.045</td>
# <td>0.0041</td>
# <td>11.0</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, GNgam; KE, chri)</td>
# <td>0.046</td>
# <td>0.0041</td>
# <td>11.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, GQgam; KE, chri)</td>
# <td>0.039</td>
# <td>0.0041</td>
# <td>9.4</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(AOcol, UGgam; KE, chri)</td>
# <td>0.033</td>
# <td>0.0041</td>
# <td>8.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(AOcol, GAgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0043</td>
# <td>4.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R-free - D(AOcol, FRgam; KE, chri)</td>
# <td>-0.051</td>
# <td>0.0072</td>
# <td>-7.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(BFcol, GHgam; KE, chri)</td>
# <td>0.020</td>
# <td>0.0038</td>
# <td>5.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(BFcol, CMgam; KE, chri)</td>
# <td>0.019</td>
# <td>0.0037</td>
# <td>5.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(BFcol, BFgam; KE, chri)</td>
# <td>0.019</td>
# <td>0.0036</td>
# <td>5.3</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(BFcol, GNgam; KE, chri)</td>
# <td>0.020</td>
# <td>0.0035</td>
# <td>5.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(BFcol, GQgam; KE, chri)</td>
# <td>0.012</td>
# <td>0.0036</td>
# <td>3.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(BFcol, UGgam; KE, chri)</td>
# <td>0.008</td>
# <td>0.0039</td>
# <td>1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(BFcol, GAgam; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0040</td>
# <td>-1.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R-free - D(BFcol, FRgam; KE, chri)</td>
# <td>-0.074</td>
# <td>0.0073</td>
# <td>-10.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, GHgam; KE, chri)</td>
# <td>0.013</td>
# <td>0.0040</td>
# <td>3.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, CMgam; KE, chri)</td>
# <td>0.012</td>
# <td>0.0039</td>
# <td>3.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, BFgam; KE, chri)</td>
# <td>0.012</td>
# <td>0.0039</td>
# <td>3.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, GNgam; KE, chri)</td>
# <td>0.013</td>
# <td>0.0038</td>
# <td>3.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, GQgam; KE, chri)</td>
# <td>0.006</td>
# <td>0.0039</td>
# <td>1.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, UGgam; KE, chri)</td>
# <td>0.001</td>
# <td>0.0040</td>
# <td>0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GNcol, GAgam; KE, chri)</td>
# <td>-0.012</td>
# <td>0.0043</td>
# <td>-2.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R-free - D(GNcol, FRgam; KE, chri)</td>
# <td>-0.080</td>
# <td>0.0075</td>
# <td>-10.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(CIcol, GHgam; KE, chri)</td>
# <td>0.022</td>
# <td>0.0038</td>
# <td>5.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(CIcol, CMgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0038</td>
# <td>5.5</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(CIcol, BFgam; KE, chri)</td>
# <td>0.021</td>
# <td>0.0037</td>
# <td>5.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(CIcol, GNgam; KE, chri)</td>
# <td>0.022</td>
# <td>0.0036</td>
# <td>6.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(CIcol, GQgam; KE, chri)</td>
# <td>0.014</td>
# <td>0.0037</td>
# <td>3.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(CIcol, UGgam; KE, chri)</td>
# <td>0.009</td>
# <td>0.0039</td>
# <td>2.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(CIcol, GAgam; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0042</td>
# <td>-0.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R-free - D(CIcol, FRgam; KE, chri)</td>
# <td>-0.072</td>
# <td>0.0074</td>
# <td>-9.7</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(GHcol, GHgam; KE, chri)</td>
# <td>0.024</td>
# <td>0.0040</td>
# <td>6.1</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(GHcol, CMgam; KE, chri)</td>
# <td>0.023</td>
# <td>0.0040</td>
# <td>5.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(GHcol, BFgam; KE, chri)</td>
# <td>0.024</td>
# <td>0.0038</td>
# <td>6.2</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3R-free - D(GHcol, GNgam; KE, chri)</td>
# <td>0.025</td>
# <td>0.0038</td>
# <td>6.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GHcol, GQgam; KE, chri)</td>
# <td>0.017</td>
# <td>0.0039</td>
# <td>4.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GHcol, UGgam; KE, chri)</td>
# <td>0.012</td>
# <td>0.0041</td>
# <td>2.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3R-free - D(GHcol, GAgam; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0043</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3R-free - D(GHcol, FRgam; KE, chri)</td>
# <td>-0.070</td>
# <td>0.0074</td>
# <td>-9.5</td>
# </tr>
# </tbody>
# </table>

# %%
def plot_test(As,Bs,Cs,Ds, blen=100000):
    # normalise inputs
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
   
    tbl = []
    tbl2 = [["Block_1","Block_2","Block_3","Block_4","Block_5","Block_6","Block_7","Block_8","Block_9","Block_10","Block_11","Block_12","Block_13","Block_14","Block_15","Block_16","Block_17","Block_18","Block_19","Block_20","Block_21","Block_22","Block_23","Block_24","Block_25","Block_26","Block_27","Block_28","Block_29","Block_30","Block_31","Block_32","Block_33","Block_34","Block_35","Block_36","Block_37","Block_38","Block_39","Block_40","Block_41","Block_42","Block_43","Block_44","Block_45","Block_46","Block_47","Block_48","Block_49","Block_50","Block_51","Block_52","Block_53","Block_54","Block_55","Block_56","Block_57","Block_58","Block_59","Block_60","Block_61","Block_62","Block_63","Block_64","Block_65","Block_66","Block_67","Block_68","Block_69","Block_70","Block_71","Block_72","Block_73","Block_74","Block_75","Block_76","Block_77","Block_78","Block_79","Block_80","Block_81","Block_82"]]
    tbl3 = [['Test']]

    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, b1, _ = f4_analysis(A, B, C, D, blen=blen)
                            test = "3R-free - D-Test(%s, %s, %s, %s)" % (A, B, C, D)
                            row = b1
                            tbl += [row]
                            row2 = [test]
                            tbl2 += [row]
                            tbl3 += [row2]
    df1 = etl.todataframe(tbl2)
    df2 = etl.todataframe(tbl3)
    results = df2.join(df1)
    tbl=np.array(tbl)
    #print (tbl)
    fig, ax = plt.subplots(figsize=(14, 4))
    # mean
    pos = callset_biallel['3R']['variants']['POS'][:]
    windows = allel.moving_statistic(loc, statistic=lambda v: [v[0], v[-1]], size=blen)
    x = np.asarray(windows).mean(axis=1)    
    y = np.median(tbl, axis=0)
    plt.plot(x, y, lw=1, label = "median", color=palette[3]) 
    
    #min and max
    y5 = np.max(tbl, axis=0)
    y6 = np.min(tbl, axis=0)
    ax.fill_between(x, y5, y6,label = "min and max", color=palette[9], alpha=.4)
    
    # interquartile range
    y1 = np.percentile(tbl, 25, axis=0)
    y2 = np.percentile(tbl, 75, axis=0)
    ax.fill_between(x, y1, y2, label = "interquartile range", color=palette[2], alpha=.6)
    # 5-95 range
    y3 = np.percentile(tbl, 5, axis=0)
    y4 = np.percentile(tbl, 95, axis=0)
    ax.fill_between(x, y3, y4,label = "5-95 range", color=palette[4], alpha=.4)

    
    ax.set_title(('ABBA BABA Test - Blocks scan (%s bp) on 3R-free') % (blen))
    sns.despine(ax=ax, offset=10)
    ax.set_xlim(loc[0], loc.max())
    ax.set_xlabel('position (bp)')
    #ax.set_ylim(0,0.018)
    sns.despine(ax=ax, offset=10)
    fig.tight_layout()
    # show a legend on the plot 
    plt.legend() 

    # function to show the plot 
    plt.show()
    
    return results, tbl, plt

# %%
results_3R, bloks_3R, plot_3R = plot_test(A,B,C,D, blen = 100000)

# %%
# load variant positions
block_starts = allel.moving_statistic(loc, statistic=np.min, size=100000)
block_stops = allel.moving_statistic(loc, statistic=np.max, size=100000)
block_widths = block_stops - block_starts
title = results_3R['Test']
### qui bisogna fare un ciclo:
for i in range(len(bloks_3R)):	
		ylim=(-.2, .2)
		fig, ax =  plt.subplots(figsize=(14, 4))
		ax.bar(block_starts, bloks_3R[i], width=block_widths, linewidth=0)
		ax.axhline(0, color='k', linestyle='--')
		ax.set_ylabel('D', rotation=0, ha='center', va='center')
		ax.set_ylim(*ylim)
		ax.set_title('%s' %(title[i]))
		sns.despine(ax=ax, offset=10)
		fig.tight_layout()   
i+=1

# %% [markdown]
# ---------------------------------
