# %% [markdown]
# # ABBA-BABA Test on 3L-free region (15 Mbp - 41 Mbp)
# Performed on:
#
#
#   - Kenya population  <b>((([ <i>An.gambiae <sub>pops</sub></i> ], [<i>An.coluzzii <sub>pops</sub></i> ]), Kenya), [ <i>An.christyi</i> ])</b>
#   - Far-west pops <b>((([ <i>An.gambiae <sub>pops</sub></i> ], [<i>Far-West<sub>pops</sub></i> ]]),  <i>An.coluzzii  <sub>pops</sub></i> ), [ <i>An.christyi</i> ])</b>
#
# In the last part of the notebook also testing Kenya vs merus and melas populations

# %%
Image(filename='data/Treemix_data/christyi/3L-free/3L-free.png')

# %%
Image(filename='images/Schermata del 2019-12-18 15-14-23.png')

# %%
# %run imports.ipynb
# %run '08222019_functions.ipynb'
import allel
import zarr
import pandas as pd
import petl as etl
import numpy as np
import matplotlib.pyplot as plt
import dask.array as da
import seaborn as sns
from IPython.display import Image
palette = sns.color_palette()

# %%
from dask_kubernetes import KubeCluster
cluster = KubeCluster(n_workers=30)
cluster
# Out:
# VBox(children=(HTML(value='<h2>KubeCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…

# %%
from dask.distributed import Client
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.35.63.177:43771' processes=0 threads=0, memory=0 B>

# %%
calldata_out= zarr.open('data/outgroup_alleles_phase2.zarr/')
calldata_biallel= zarr.open('data/phase2_biallel_allele_count.zarr/')

# %%
an_col = 'AOcol', 'BFcol', 'GNcol', 'CIcol', 'GHcol'
an_gam = 'GHgam', 'CMgam', 'BFgam', 'GNgam', 'GQgam', 'UGgam', 'GAgam', 'FRgam'
an_fw = 'GM', 'GW'
out_species = ['arab', 'chri', 'epir', 'mela', 'meru', 'quad']

# %%
def count_alleles_pos(chrom, start, stop):
    df_samples = pd.read_csv("samples.meta.txt", sep="\t")
    pos_all = allel.SortedIndex(callset_biallel[chrom]["variants/POS"])
    loc = pos_all.locate_range(start,stop)
    gt = allel.GenotypeDaskArray(callset_biallel[chrom]['calldata/GT'])
    subpops = metadata.groupby('population').indices
    ac_subpops = allel.AlleleCountsChunkedTable(gt[loc].count_alleles_subpops(subpops))
    return ac_subpops

# %%
ac_3L_free = count_alleles_pos('3L', 15_000_000, 41_000_000)
ac_3L_free
# Out:
# <AlleleCountsChunkedTable shape=(5989818,) dtype=[('AOcol', '<i4', (2,)), ('BFcol', '<i4', (2,)), ('BFgam', '<i4', (2,)), ('CIcol', '<i4', (2,)), ('CMgam', '<i4', (2,)), ('FRgam', '<i4', (2,)), ('GAgam', '<i4', (2,)), ('GHcol', '<i4', (2,)), ('GHgam', '<i4', (2,)), ('GM', '<i4', (2,)), ('GNcol', '<i4', (2,)), ('GNgam', '<i4', (2,)), ('GQgam', '<i4', (2,)), ('GW', '<i4', (2,)), ('KE', '<i4', (2,)), ('UGgam', '<i4', (2,))]
#    nbytes=731.2M
#    values=builtins.dict>

# %%
loc = (allel.SortedIndex(callset_biallel['3L']["variants/POS"])).locate_range(15_000_000, 41_000_000)
loc
# Out:
# slice(1667041, 7656859, None)

# %%
ac_out_3L_free = {pop: calldata_out['3L'][pop][loc] for pop in out_species}

# %%
ac_out_3L_free.keys()
# Out:
# dict_keys(['arab', 'chri', 'epir', 'mela', 'meru', 'quad'])

# %% [markdown]
# -------------------------------------------------------
# ## Perform the ABBA-BABA test
# Using the old script

# %%
chromosomes = ['3L']

# %%
ac_cache = dict()

def load_ac(pop):
    if (pop) in ac_cache:
        return ac_cache[pop]
    else:
        if pop in out_species:
            ac = allel.AlleleCountsChunkedArray(ac_out_3L_free[pop])
        else:
            ac = ac_3L_free[pop]
            ac_cache[pop] = ac
        return ac
    
fourpop_cache = dict()

# %%
#this is the function that perform the test
def f4_analysis(A, B, C, D, blen=100000, plot=False, ax=None):
    
    key = (A, B, C, D, blen)
    if key in fourpop_cache:
        # re-use from cache
        d, d_se, d_z, d_vb, d_vj = fourpop_cache[key]
        
    else:
        # load allele counts
        aca = load_ac(A)
        acb = load_ac(B)
        acc = load_ac(C)
        acd = load_ac(D)

        # run D test
        d, d_se, d_z, d_vb, d_vj = allel.blockwise_patterson_d(aca, acb, acc, acd, blen=blen)
        
        # cache for re-use
        fourpop_cache[key] = d, d_se, d_z, d_vb, d_vj
    
    return d, d_se, d_z, d_vb, d_vj

#this is the function that give me to display multiple tests on a table
def f4_analyses(As, Bs, Cs, Ds, blen=100000):
    
    # normalise inputs
    if not isinstance(As, (list, tuple)):
        As = [As]
    if not isinstance(Bs, (list, tuple)):
        Bs = [Bs]
    if not isinstance(Cs, (list, tuple)):
        Cs = [Cs]
    if not isinstance(Ds, (list, tuple)):
        Ds = [Ds]
        
    # setup output table
    tbl = [['test', 'D', 'SE', 'Z']]
    for A in As:
        for B in Bs:
            if A != B:
                for C in Cs:
                    for D in Ds:
                        if C != D:
                            d, d_se, d_z, _, _ = f4_analysis(A, B, C, D, blen=blen)
                            test = '3L-free (15-41Mbp)  -  D(%s, %s; %s, %s)' % (A, B, C, D)
                            row = [test, d, d_se, d_z]
                            tbl += [row]
    
    return tbl

def tbl_display(tbl):
        # display results
    (etl
     .wrap(tbl)
     .interpolate('D', '%.3f')
     .interpolate('SE', '%.4f')
     .interpolate('Z', '%.1f')
     .displayall(index_header=False, 
                 tr_style=lambda row: 'background-color: %s' % ('#afa' if float(row.Z) > 5 else '#aaf' if float(row.Z) < -5 else 'white')))
    

    
def tbl_d_plot(table, title):
    # plot
    tbl = etl.wrap(table).sort('test')
    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(20, tbl.nrows()*.2))
    
    ## First Plot - Bar Plot
    x = tbl.values('D').array()
    y = np.arange(tbl.nrows())
    ax1.axvline(0, color='r', lw=1)
    xerr = tbl.values('SE').array()
    ax1.errorbar(x, y, xerr=xerr, fmt='o', lw=1, color='k', mew=1, mfc='k')
    ax1.set_yticks(y)
    ylbls = ['%s; Z = %.1f' % (v.test, v.Z) for v in tbl.records()]
    ax1.set_yticklabels(ylbls)
    ax1.yaxis.tick_right()
    ax1.xaxis.tick_top()
    ax1.xaxis.set_label_position('top')
    ax1.set_xlim(-.2,.2)
    ax1.set_ylim(-1, y.size)
    ax1.grid(axis='both', color='#dddddd')
    ax1.set_xlabel("Patterson's $D$ Barplot")
    fig.suptitle('%s' % (title), y=1.02, fontsize=16)

    ## Second plot - Heatmap
    results = etl.todataframe(tbl)
    df1 = results[['test', 'D','Z']].round(2)
    heatmap1_data = pd.pivot_table(df1, values='Z', 
                     index=['test'], 
                     columns='D')
    lm = sns.heatmap(heatmap1_data, cmap="RdBu", vmin=15, vmax=-15, annot=True)
    ax2 = lm.axes
    ax2.set_xlim(-.7)
    ax2.set_ylim(40.4)
    ax2.xaxis.set_label_position('top')
    ax2.xaxis.tick_top()
    plt.xticks(rotation=70)
    ax2.set_xlabel("Patterson's $D$ Heatmap")
    ax2.invert_yaxis()
    plt.text(1.02, 0.5, 'Z-score', {'fontsize': 15},
             horizontalalignment='left',
             verticalalignment='center',
             rotation=90,
             clip_on=False,
             transform=plt.gca().transAxes)

    ax2.grid(False, 'major')
    ax2.grid(True, 'minor')
    ax2.set_yticks([t - 0.5 for t in ax2.get_yticks()], minor=True)
    sns.despine()
    fig.tight_layout()
    plt.show()

# %%
A = an_gam
B = an_col
C = 'KE'
D = 'chri'
D_test = f4_analyses(A, B, C, D)

# %%
tbl_display(D_test)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, AOcol; KE, chri)</td>
# <td>-0.029</td>
# <td>0.0034</td>
# <td>-8.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, BFcol; KE, chri)</td>
# <td>-0.000</td>
# <td>0.0029</td>
# <td>-0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GNcol; KE, chri)</td>
# <td>0.003</td>
# <td>0.0050</td>
# <td>0.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, CIcol; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0036</td>
# <td>-0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GHcol; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0036</td>
# <td>-1.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, AOcol; KE, chri)</td>
# <td>-0.028</td>
# <td>0.0037</td>
# <td>-7.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, BFcol; KE, chri)</td>
# <td>0.001</td>
# <td>0.0032</td>
# <td>0.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GNcol; KE, chri)</td>
# <td>0.005</td>
# <td>0.0054</td>
# <td>0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, CIcol; KE, chri)</td>
# <td>-0.002</td>
# <td>0.0040</td>
# <td>-0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GHcol; KE, chri)</td>
# <td>-0.004</td>
# <td>0.0039</td>
# <td>-1.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, AOcol; KE, chri)</td>
# <td>-0.030</td>
# <td>0.0037</td>
# <td>-8.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, BFcol; KE, chri)</td>
# <td>-0.001</td>
# <td>0.0032</td>
# <td>-0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GNcol; KE, chri)</td>
# <td>0.002</td>
# <td>0.0054</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, CIcol; KE, chri)</td>
# <td>-0.004</td>
# <td>0.0040</td>
# <td>-1.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GHcol; KE, chri)</td>
# <td>-0.006</td>
# <td>0.0038</td>
# <td>-1.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, AOcol; KE, chri)</td>
# <td>-0.032</td>
# <td>0.0037</td>
# <td>-8.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, BFcol; KE, chri)</td>
# <td>-0.003</td>
# <td>0.0032</td>
# <td>-0.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GNcol; KE, chri)</td>
# <td>0.001</td>
# <td>0.0054</td>
# <td>0.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, CIcol; KE, chri)</td>
# <td>-0.005</td>
# <td>0.0040</td>
# <td>-1.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GHcol; KE, chri)</td>
# <td>-0.008</td>
# <td>0.0039</td>
# <td>-2.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, AOcol; KE, chri)</td>
# <td>-0.022</td>
# <td>0.0042</td>
# <td>-5.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, BFcol; KE, chri)</td>
# <td>0.007</td>
# <td>0.0038</td>
# <td>1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GNcol; KE, chri)</td>
# <td>0.011</td>
# <td>0.0057</td>
# <td>1.9</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, CIcol; KE, chri)</td>
# <td>0.005</td>
# <td>0.0045</td>
# <td>1.0</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GHcol; KE, chri)</td>
# <td>0.002</td>
# <td>0.0043</td>
# <td>0.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, AOcol; KE, chri)</td>
# <td>-0.018</td>
# <td>0.0044</td>
# <td>-4.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, BFcol; KE, chri)</td>
# <td>0.010</td>
# <td>0.0039</td>
# <td>2.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GNcol; KE, chri)</td>
# <td>0.014</td>
# <td>0.0060</td>
# <td>2.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, CIcol; KE, chri)</td>
# <td>0.008</td>
# <td>0.0047</td>
# <td>1.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GHcol; KE, chri)</td>
# <td>0.005</td>
# <td>0.0046</td>
# <td>1.1</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GAgam, AOcol; KE, chri)</td>
# <td>-0.010</td>
# <td>0.0041</td>
# <td>-2.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GAgam, BFcol; KE, chri)</td>
# <td>0.018</td>
# <td>0.0039</td>
# <td>4.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GAgam, GNcol; KE, chri)</td>
# <td>0.022</td>
# <td>0.0059</td>
# <td>3.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GAgam, CIcol; KE, chri)</td>
# <td>0.016</td>
# <td>0.0046</td>
# <td>3.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GAgam, GHcol; KE, chri)</td>
# <td>0.013</td>
# <td>0.0046</td>
# <td>2.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free (15-41Mbp)  -  D(FRgam, AOcol; KE, chri)</td>
# <td>0.046</td>
# <td>0.0079</td>
# <td>5.8</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free (15-41Mbp)  -  D(FRgam, BFcol; KE, chri)</td>
# <td>0.072</td>
# <td>0.0081</td>
# <td>8.9</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free (15-41Mbp)  -  D(FRgam, GNcol; KE, chri)</td>
# <td>0.075</td>
# <td>0.0094</td>
# <td>8.0</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free (15-41Mbp)  -  D(FRgam, CIcol; KE, chri)</td>
# <td>0.069</td>
# <td>0.0084</td>
# <td>8.2</td>
# </tr>
# <tr style='background-color: #afa'>
# <td>3L-free (15-41Mbp)  -  D(FRgam, GHcol; KE, chri)</td>
# <td>0.067</td>
# <td>0.0084</td>
# <td>7.9</td>
# </tr>
# </tbody>
# </table>

# %%
tbl_d_plot(D_test, 'ABBA-BABA Test Chromosome 3L (15-41Mbp)')

# %% [markdown]
# ---------------------------

# %%
A = an_gam
B = an_fw
C = an_col
D = 'chri'
D_test = f4_analyses(A, B, C, D)

# %%
tbl_display(D_test)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>test</th>
# <th>D</th>
# <th>SE</th>
# <th>Z</th>
# </tr>
# </thead>
# <tbody>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GM; AOcol, chri)</td>
# <td>0.001</td>
# <td>0.0025</td>
# <td>0.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GM; BFcol, chri)</td>
# <td>-0.021</td>
# <td>0.0021</td>
# <td>-10.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GM; GNcol, chri)</td>
# <td>-0.035</td>
# <td>0.0035</td>
# <td>-10.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GM; CIcol, chri)</td>
# <td>-0.029</td>
# <td>0.0024</td>
# <td>-12.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GM; GHcol, chri)</td>
# <td>-0.029</td>
# <td>0.0023</td>
# <td>-12.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GW; AOcol, chri)</td>
# <td>0.001</td>
# <td>0.0027</td>
# <td>0.5</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GW; BFcol, chri)</td>
# <td>-0.023</td>
# <td>0.0022</td>
# <td>-10.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GW; GNcol, chri)</td>
# <td>-0.039</td>
# <td>0.0039</td>
# <td>-10.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GW; CIcol, chri)</td>
# <td>-0.032</td>
# <td>0.0026</td>
# <td>-12.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GHgam, GW; GHcol, chri)</td>
# <td>-0.032</td>
# <td>0.0025</td>
# <td>-12.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GM; AOcol, chri)</td>
# <td>-0.000</td>
# <td>0.0025</td>
# <td>-0.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GM; BFcol, chri)</td>
# <td>-0.023</td>
# <td>0.0021</td>
# <td>-11.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GM; GNcol, chri)</td>
# <td>-0.038</td>
# <td>0.0039</td>
# <td>-9.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GM; CIcol, chri)</td>
# <td>-0.032</td>
# <td>0.0026</td>
# <td>-12.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GM; GHcol, chri)</td>
# <td>-0.031</td>
# <td>0.0025</td>
# <td>-12.7</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GW; AOcol, chri)</td>
# <td>-0.000</td>
# <td>0.0026</td>
# <td>-0.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GW; BFcol, chri)</td>
# <td>-0.025</td>
# <td>0.0022</td>
# <td>-11.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GW; GNcol, chri)</td>
# <td>-0.041</td>
# <td>0.0042</td>
# <td>-9.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GW; CIcol, chri)</td>
# <td>-0.035</td>
# <td>0.0028</td>
# <td>-12.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(CMgam, GW; GHcol, chri)</td>
# <td>-0.034</td>
# <td>0.0027</td>
# <td>-12.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GM; AOcol, chri)</td>
# <td>-0.001</td>
# <td>0.0026</td>
# <td>-0.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GM; BFcol, chri)</td>
# <td>-0.023</td>
# <td>0.0021</td>
# <td>-10.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GM; GNcol, chri)</td>
# <td>-0.038</td>
# <td>0.0040</td>
# <td>-9.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GM; CIcol, chri)</td>
# <td>-0.032</td>
# <td>0.0027</td>
# <td>-11.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GM; GHcol, chri)</td>
# <td>-0.031</td>
# <td>0.0026</td>
# <td>-12.2</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GW; AOcol, chri)</td>
# <td>-0.001</td>
# <td>0.0027</td>
# <td>-0.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GW; BFcol, chri)</td>
# <td>-0.025</td>
# <td>0.0023</td>
# <td>-11.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GW; GNcol, chri)</td>
# <td>-0.041</td>
# <td>0.0042</td>
# <td>-9.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GW; CIcol, chri)</td>
# <td>-0.035</td>
# <td>0.0029</td>
# <td>-11.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(BFgam, GW; GHcol, chri)</td>
# <td>-0.034</td>
# <td>0.0028</td>
# <td>-12.3</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GM; AOcol, chri)</td>
# <td>-0.003</td>
# <td>0.0027</td>
# <td>-1.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GM; BFcol, chri)</td>
# <td>-0.024</td>
# <td>0.0023</td>
# <td>-10.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GM; GNcol, chri)</td>
# <td>-0.039</td>
# <td>0.0040</td>
# <td>-9.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GM; CIcol, chri)</td>
# <td>-0.033</td>
# <td>0.0028</td>
# <td>-11.6</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GM; GHcol, chri)</td>
# <td>-0.033</td>
# <td>0.0026</td>
# <td>-12.4</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GW; AOcol, chri)</td>
# <td>-0.002</td>
# <td>0.0028</td>
# <td>-0.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GW; BFcol, chri)</td>
# <td>-0.026</td>
# <td>0.0024</td>
# <td>-11.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GW; GNcol, chri)</td>
# <td>-0.042</td>
# <td>0.0043</td>
# <td>-9.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GW; CIcol, chri)</td>
# <td>-0.036</td>
# <td>0.0030</td>
# <td>-11.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GNgam, GW; GHcol, chri)</td>
# <td>-0.036</td>
# <td>0.0029</td>
# <td>-12.5</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GM; AOcol, chri)</td>
# <td>0.012</td>
# <td>0.0025</td>
# <td>4.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GM; BFcol, chri)</td>
# <td>-0.017</td>
# <td>0.0021</td>
# <td>-8.4</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GM; GNcol, chri)</td>
# <td>-0.033</td>
# <td>0.0036</td>
# <td>-9.0</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GM; CIcol, chri)</td>
# <td>-0.026</td>
# <td>0.0024</td>
# <td>-10.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GM; GHcol, chri)</td>
# <td>-0.025</td>
# <td>0.0024</td>
# <td>-10.6</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GW; AOcol, chri)</td>
# <td>0.012</td>
# <td>0.0026</td>
# <td>4.7</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GW; BFcol, chri)</td>
# <td>-0.020</td>
# <td>0.0022</td>
# <td>-8.9</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GW; GNcol, chri)</td>
# <td>-0.036</td>
# <td>0.0039</td>
# <td>-9.2</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GW; CIcol, chri)</td>
# <td>-0.029</td>
# <td>0.0026</td>
# <td>-11.1</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(GQgam, GW; GHcol, chri)</td>
# <td>-0.028</td>
# <td>0.0026</td>
# <td>-10.8</td>
# </tr>
# <tr style='background-color: white'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GM; AOcol, chri)</td>
# <td>-0.001</td>
# <td>0.0023</td>
# <td>-0.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GM; BFcol, chri)</td>
# <td>-0.025</td>
# <td>0.0020</td>
# <td>-12.3</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GM; GNcol, chri)</td>
# <td>-0.040</td>
# <td>0.0037</td>
# <td>-10.8</td>
# </tr>
# <tr style='background-color: #aaf'>
# <td>3L-free (15-41Mbp)  -  D(UGgam, GM; CIcol, chri)</td>
# <td>-0.034</td>
# <td>0.0024</

# %%
tbl_d_plot(D_test, 'ABBA-BABA Test Chromosome 3L (15-41Mbp)')

# %% [markdown]
# ----------
