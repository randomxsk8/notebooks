# %% [markdown]
# # Population Branch Statistics (PBS)

# %%
# %run "imports.ipynb"

# %%
ac_biallel = zarr.open('data/phase2_biallel_allele_count.zarr')
outgroup_allele_counts= zarr.open('data/outgroup_alleles_phase2.zarr')
callset = callset_biallel

# %%
contigs = ['2R','2L','3R','3L', 'X']

# %% [markdown]
# ----------------------------------------------

# %%
def pbs(chrom, pop1, pop2, pop3, window_size=100, min_maf=0.02, normed=True):
    
    # load variant positions
    loc_pass_variants = callset[chrom]['variants/FILTER_PASS'][:]
    pos = callset[chrom]['variants/POS'][:][loc_pass_variants]
    
    # load allele counts
    ac1 = allel.AlleleCountsArray(ac_biallel[chrom][pop1])
    ac2 = allel.AlleleCountsArray(ac_biallel[chrom][pop2])
    ac3 = allel.AlleleCountsArray(outgroup_allele_counts[chrom][pop3])

    # locate segregating variants at sufficient frequency
    ac = ac1 + ac2 + ac3
    loc_seg = (ac.to_frequencies()[:, :2].min(axis=1) > min_maf)
    pos = pos[loc_seg]
    ac1 = ac1[loc_seg]
    ac2 = ac2[loc_seg]
    ac3 = ac3[loc_seg]
    
    # setup windows
    starts = allel.moving_statistic(pos, statistic=lambda v: v[0], size=window_size)
    starts[0] = 1  # fix to start of sequence
    ends = np.append(starts[1:] - 1, [np.max(pos)])

    # compute pbs
    res = allel.pbs(ac1, ac2, ac3, window_size=window_size, normed=normed)

    return starts, ends, res

def pbs_plot (chrom, pop1, pop2, pop3, window_size=100, min_maf=0.02, normed=True):
    starts, ends, y = pbs(chrom, pop1, pop2, pop3)
    fig, ax = plt.subplots(figsize=(14, 3))
    x = (starts + ends) / 2
    sns.despine(ax=ax, offset=10)
    ax.set_xlim(0, x.max())
    ax.plot(x, y, marker='o', linestyle=' ', mfc='none', mec='k', markersize=2)
    ax.set_xlabel('Genome position (bp)')
    ax.set_ylabel('PBS');
    


def plot_genes_remastered(chrom, pos):
    plot_genes(genome, geneset_fn, chrom, pos-100, pos+100, label=True, label_rotation=90, height=0.5)
    
    
    
    
def locate_genes(chrom, value, pop1, pop2, pop3):    
    col_names = ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']
    df = pd.read_csv('/home/jovyan/notebooks/data/Anopheles-gambiae-PEST_BASEFEATURES_AgamP4.2.sorted.gff3.gz', compression='gzip',
                             sep='\t', comment='#', low_memory=False,
                             header=None, names=col_names)
    
    results = pbs(chrom, pop1, pop2, pop3)
    over30 = results[0][results[2] > value]
    
    df2 = pd.DataFrame([])
    for i in range(len(over30)):
        a=(df[(df.seqid == chrom) & (df.type == 'gene') & (df['start'] <= over30[i]-100) & (df['end'] >= over30[i]+100)])
        
        df2 = df2.append(a)
        df2.drop_duplicates(keep=False,inplace=True)

    log('Found', len(over30), 'SNPs with PBS values above', value, '\n', 'Total genes found:', len(df2))

    return df2




def plot_genes_pbs(chrom, pop1, pop2, pop3):
    results = pbs(chrom, pop1, pop2, pop3)
    over30 = results[0][results[2] > 0.2]
    print (over30)
    for i in range(len(over30)):
        plt.figure()
        plot_genes_remastered(chrom, over30[i])

# %% [markdown]
# ## PBS by sympatric populations using <i>An.arabiensis</i> population as outgroup

# %% [markdown]
# ### Chromosome 3R

# %%
pbs_plot('3R', 'BFcol', 'BFgam', 'arab')
# Out:
# findfont: Font family ['arial'] not found. Falling back to DejaVu Sans.

# %%
locate_genes('3R', 0.4, 'BFcol', 'BFgam', 'arab')
# Out:
# Found 3 SNPs with PBS values above 0.4
#  Total genes found: 1
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
#        seqid      source  type     start       end score strand phase  \
# 155636    3R  VectorBase  gene  52903957  52937651     .      -     .
#
#                                   attributes
# 155636  ID=AGAP010303;biotype=protein_coding

# %%
locate_genes('3R', 0.3, 'BFcol', 'BFgam', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 23 SNPs with PBS values above 0.3
#  Total genes found: 3
#        seqid      source  type     start       end score strand phase  \
# 119891    3R  VectorBase  gene     82151    142545     .      +     .
# 155628    3R  VectorBase  gene  52851999  52854757     .      -     .
# 155636    3R  VectorBase  gene  52903957  52937651     .      -     .
#
#                                   attributes
# 119891  ID=AGAP007736;biotype=protein_coding
# 155628  ID=AGAP010302;biotype=protein_coding
# 155636  ID=AGAP010303;biotype=protein_coding

# %% [markdown]
# ------------------------------

# %%
pbs_plot('3R', 'GHcol', 'GHgam', 'arab')

# %%
locate_genes('3R', 0.4, 'GHcol', 'GHgam', 'arab')
# Out:
# Found 0 SNPs with PBS values above 0.4
#  Total genes found: 0
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Empty DataFrame
# Columns: []
# Index: []

# %%
locate_genes('3R', 0.3, 'GHcol', 'GHgam', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 8 SNPs with PBS values above 0.3
#  Total genes found: 1
#        seqid      source  type     start       end score strand phase  \
# 155636    3R  VectorBase  gene  52903957  52937651     .      -     .
#
#                                   attributes
# 155636  ID=AGAP010303;biotype=protein_coding

# %% [markdown]
# -------------------

# %%
pbs_plot('3R', 'GNcol', 'GNgam', 'arab')

# %%
locate_genes('3R', 0.4, 'GNcol', 'GNgam', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 10 SNPs with PBS values above 0.4
#  Total genes found: 1
#        seqid      source  type     start       end score strand phase  \
# 147259    3R  VectorBase  gene  39950254  39970989     .      -     .
#
#                                   attributes
# 147259  ID=AGAP009716;biotype=protein_coding

# %%
locate_genes('3R', 0.3, 'GNcol', 'GNgam', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 38 SNPs with PBS values above 0.3
#  Total genes found: 9
#        seqid      source  type     start       end score strand phase  \
# 119834    3R  VectorBase  gene     24056     39486     .      +     .
# 119870    3R  VectorBase  gene     57849     62977     .      +     .
# 119939    3R  VectorBase  gene    172973    173928     .      +     .
# 141770    3R  VectorBase  gene  30300622  30308216     .      -     .
# 147259    3R  VectorBase  gene  39950254  39970989     .      -     .
# 150216    3R  VectorBase  gene  46148454  46164104     .      +     .
# 151981    3R  VectorBase  gene  48817865  48884835     .      -     .
# 154860    3R  VectorBase  gene  51727896  51751309     .      +     .
# 155659    3R  VectorBase  gene  52951761  52996140     .      +     .
#
#                                   attributes
# 119834  ID=AGAP007732;biotype=protein_coding
# 119870  ID=AGAP007734;biotype=protein_coding
# 119939  ID=AGAP007740;biotype=protein_coding
# 141770  ID=AGAP009268;biotype=protein_coding
# 147259  ID=AGAP009716;biotype=protein_coding
# 150216  ID=AGAP009951;biotype=protein_coding
# 151981  ID=AGAP010090;biotype=protein_coding
# 154860  ID=AGAP010259;biotype=protein_coding
# 155659  ID=AGAP010304;biotype=protein_coding

# %%
locate_genes('3R', 0.2, 'GNcol', 'GNgam', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 365 SNPs with PBS values above 0.2
#  Total genes found: 53
#        seqid      source  type     start       end score strand phase  \
# 119861    3R  VectorBase  gene     39643     41560     .      +     .
# 119870    3R  VectorBase  gene     57849     62977     .      +     .
# 119939    3R  VectorBase  gene    172973    173928     .      +     .
# 119971    3R  VectorBase  gene    183531    191944     .      +     .
# 120029    3R  VectorBase  gene    228685    256328     .      +     .
# 123446    3R  VectorBase  gene   3273438   3275122     .      -     .
# 125986    3R  VectorBase  gene   5874203   5875164     .      -     .
# 126704    3R  VectorBase  gene   6376711   6377745     .      -     .
# 128369    3R  VectorBase  gene   8803846   8861386     .      -     .
# 128447    3R  VectorBase  gene   8838946   8852517     .      +     .
# 140143    3R  VectorBase  gene  27782815  27933882     .      -     .
# 140486    3R  VectorBase  gene  28368508  28377103     .      -     .
# 140505    3R  VectorBase  gene  28568855  28571263     .      -     .
# 140537    3R  VectorBase  gene  28576092  28590073     .      +     .
# 140624    3R  VectorBase  gene  28598871  28599816     .      -     .
# 140642    3R  VectorBase  gene  28601368  28602280     .      -     .
# 140680    3R  VectorBase  gene  28646812  28654237     .      +     .
# 140746    3R  VectorBase  gene  28697024  28745886     .      -     .
# 140785    3R  VectorBase  gene  28747856  28807725     .      -     .
# 140981    3R  VectorBase  gene  28858149  28860047     .      +     .
# 141067    3R  VectorBase  gene  28897945  28901664     .      -     .
# 141186    3R  VectorBase  gene  29093874  29103367     .      -     .
# 141260    3R  VectorBase  gene  29270042  29273911     .      -     .
# 141770    3R  VectorBase  gene  30300622  30308216     .      -     .
# 142663    3R  VectorBase  gene  31516881  31520891     .      -     .
# 147073    3R  VectorBase  gene  38993868  39017067     .      -     .
# 147259    3R  VectorBase  gene  39950254  39970989     .      -     .
# 147363    3R  VectorBase  gene  41206908  41229906     .      -     .
# 147547    3R  VectorBase  gene  42036462  42046551     .      +     .
# 147638    3R  VectorBase  gene  42077781  42087339     .      -     .
# 148206    3R  VectorBase  gene  43287963  43289420     .      -     .
# 148288    3R  VectorBase  gene  43431091  43432588     .      -     .
# 148304    3R  VectorBase  gene  43449020  43471781     .      +     .
# 149195    3R  VectorBase  gene  44550269  44570066     .      +     .
# 149203    3R  VectorBase  gene  44558522  44561275     .      -     .
# 149594    3R  VectorBase  gene  44948747  44962188     .      +     .
# 149720    3R  VectorBase  gene  45197982  45200093     .      -     .
# 149957    3R  VectorBase  gene  45442323  45479458     .      -     .
# 150033    3R  VectorBase  gene  45691228  45703921     .      +     .
# 150216    3R  VectorBase  gene  46148454  46164104     .      +     .
# 150240    3R  VectorBase  gene  46187605  46206053     .      +     .
# 151238    3R  VectorBase  gene  48079043  48083969     .      -     .
# 151981    3R  VectorBase  gene  48817865  48884835     .      -     .
# 152592    3R  VectorBase  gene  49370055  49390808     .      -     .
# 153090    3R  VectorBase  gene  49486871  49490420     .      -     .
# 153239    3R  VectorBase  gene  49599773  49642633     .      -     .
# 153291    3R  VectorBase  gene  49749614  49758102     .      +     .
# 153317    3R  VectorBase  gene  49778787  49791943     .      +     .
# 154233    3R  VectorBase  gene  50961498  50976999     .      +     .
# 154568    3R  VectorBase  gene  51394010  51407462     .      +     .
# 155012    3R  VectorBase  gene  51820780  51844428     .      +     .
# 155095    3R  VectorBase  gene  51882060  51911589     .      +     .
# 155659    3R  VectorBase  gene  52951761  52996140     .      +     .
#
#                                   attributes
# 119861  ID=AGAP007733;biotype=protein_coding
# 119870  ID=AGAP007734;biotype=protein_coding
# 119939  ID=AGAP007740;biotype=protein_coding
# 119971  ID=AGAP007743;biotype=protein_coding
# 120029  ID=AGAP007751;biotype=protein_coding
# 123446  ID=AGAP007950;biotype=protein_coding
# 125986  ID=AGAP013737;biotype=protein_coding
# 126704  ID=AGAP008173;biotype=protein_coding
# 128369  ID=AGAP008305;biotype=protein_coding
# 128447  ID=AGAP008310;biotype=protein_coding
# 140143  ID=AGAP009160;biotype=protein_coding
# 140486  ID=AGAP009183;biotype=protein_coding
# 140505  ID=AGAP009185;biotype=protein_coding
# 140537  ID=AGAP009189;biotype=protein_coding
# 140624  ID=AGAP009195;biotype=protein_coding
# 140642  ID=AGAP009197;biotype=protein_coding
# 140680  ID=AGAP009201;biotype=protein_coding
# 140746  ID=AGAP009207;biotype=protein_coding
# 140785  ID=AGAP009210;biotype=protein_coding
# 140981  ID=AGAP009221;biotype=protein_coding
# 141067  ID=AGAP009226;biotype=protein_coding
# 141186  ID=AGAP009239;biotype=protein_coding
# 141260  ID=AGAP009243;biotype=protein_coding
# 141770  ID=AGAP009268;biotype=protein_coding
# 142663  ID=AGAP009333;biotype=protein_coding
# 147073  ID=AGAP009697;biotype=protein_coding
# 147259  ID=AGAP009716;biotype=protein_coding
# 147363  ID=AGAP009723;biotype=protein_coding
# 147547  ID=AGAP009736;biotype=protein_coding
# 147638  ID=AGAP009744;biotype=protein_coding
# 148206  ID=AGAP009787;biotype=protein_coding
# 148288  ID=AGAP009793;biotype=protein_coding
# 148304  ID=AGAP009795;biotype=protein_coding
# 149195  ID=AGAP009862;biotype=protein_coding
# 149203  ID=AGAP009863;biotype=protein_coding
# 149594  ID=AGAP009897;biotype=protein_coding
# 149720  ID=AGAP009910;biotype=protein_coding
# 149957  ID=AGAP009932;biotype=protein_coding
# 150033  ID=AGAP009937;biotype=protein_coding
# 150216  ID=AGAP009951;biotype=protein_coding
# 150240  ID=AGAP009953;biotype=protein_coding
# 151238  ID=AGAP010036;biotype=protein_coding
# 151981  ID=AGAP010090;biotype=protein_coding
# 152592  ID=AGAP010142;biotype=protein_coding
# 153090  ID=AGAP010149;biotype=protein_coding
# 153239  ID=AGAP010158;biotype=protein_coding
# 153291  ID=AGAP010162;biotype=protein_coding
# 153317  ID=AGAP010164;biotype=protein_coding
# 154233  ID=AGAP010221;biotype=protein_coding
# 154568  ID=AGAP010239;biotype=protein_coding
# 155012  ID=AGAP010265;biotype=protein_coding
# 155095  ID=AGAP010268;biotype=protein_coding
# 155659  ID=AGAP010304;biotype=protein_coding

# %% [markdown]
# --------------------

# %% [markdown]
# ## Test for coluzzii populations with Angola and arabiensis

# %%
pbs_plot('3R', 'BFcol', 'AOcol', 'arab')

# %%
locate_genes('3R', 0.2, 'BFcol', 'AOcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 11 SNPs with PBS values above 0.2
#  Total genes found: 3
#        seqid      source  type     start       end score strand phase  \
# 130675    3R  VectorBase  gene  10915406  10917604     .      -     .
# 155602    3R  VectorBase  gene  52655670  52657280     .      +     .
# 155628    3R  VectorBase  gene  52851999  52854757     .      -     .
#
#                                   attributes
# 130675  ID=AGAP008467;biotype=protein_coding
# 155602  ID=AGAP010298;biotype=protein_coding
# 155628  ID=AGAP010302;biotype=protein_coding

# %%
pbs_plot('3R', 'GNcol', 'AOcol', 'arab')

# %%
locate_genes('3R', 0.2, 'GNcol', 'AOcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 52 SNPs with PBS values above 0.2
#  Total genes found: 17
#        seqid      source  type     start       end score strand phase  \
# 123455    3R  VectorBase  gene   3275939   3278326     .      +     .
# 128369    3R  VectorBase  gene   8803846   8861386     .      -     .
# 128447    3R  VectorBase  gene   8838946   8852517     .      +     .
# 133965    3R  VectorBase  gene  15929030  15973388     .      -     .
# 140537    3R  VectorBase  gene  28576092  28590073     .      +     .
# 140746    3R  VectorBase  gene  28697024  28745886     .      -     .
# 140785    3R  VectorBase  gene  28747856  28807725     .      -     .
# 145485    3R  VectorBase  gene  36297895  36333175     .      +     .
# 147638    3R  VectorBase  gene  42077781  42087339     .      -     .
# 147741    3R  VectorBase  gene  42361196  42365395     .      +     .
# 149370    3R  VectorBase  gene  44663896  44669862     .      -     .
# 150240    3R  VectorBase  gene  46187605  46206053     .      +     .
# 150595    3R  VectorBase  gene  47149747  47163522     .      -     .
# 153730    3R  VectorBase  gene  49983895  50074391     .      -     .
# 154233    3R  VectorBase  gene  50961498  50976999     .      +     .
# 154701    3R  VectorBase  gene  51542864  51554877     .      -     .
# 154860    3R  VectorBase  gene  51727896  51751309     .      +     .
#
#                                   attributes
# 123455  ID=AGAP007951;biotype=protein_coding
# 128369  ID=AGAP008305;biotype=protein_coding
# 128447  ID=AGAP008310;biotype=protein_coding
# 133965  ID=AGAP008712;biotype=protein_coding
# 140537  ID=AGAP009189;biotype=protein_coding
# 140746  ID=AGAP009207;biotype=protein_coding
# 140785  ID=AGAP009210;biotype=protein_coding
# 145485  ID=AGAP009566;biotype=protein_coding
# 147638  ID=AGAP009744;biotype=protein_coding
# 147741  ID=AGAP009752;biotype=protein_coding
# 149370  ID=AGAP009877;biotype=protein_coding
# 150240  ID=AGAP009953;biotype=protein_coding
# 150595  ID=AGAP009983;biotype=protein_coding
# 153730  ID=AGAP010184;biotype=protein_coding
# 154233  ID=AGAP010221;biotype=protein_coding
# 154701  ID=AGAP010245;biotype=protein_coding
# 154860  ID=AGAP010259;biotype=protein_coding

# %%
pbs_plot('3R', 'CIcol', 'AOcol', 'arab')

# %%
locate_genes('3R', 0.2, 'CIcol', 'AOcol', 'arab')
# Out:
# Found 4 SNPs with PBS values above 0.2
#  Total genes found: 1
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
#        seqid      source  type     start       end score strand phase  \
# 140583    3R  VectorBase  gene  28591663  28592475     .      -     .
#
#                                   attributes
# 140583  ID=AGAP009190;biotype=protein_coding

# %%
pbs_plot('3R', 'GHcol', 'AOcol', 'arab')

# %%
locate_genes('3R', 0.2, 'GHcol', 'AOcol', 'arab')
# Out:
# Found 5 SNPs with PBS values above 0.2
#  Total genes found: 0
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Empty DataFrame
# Columns: [seqid, source, type, start, end, score, strand, phase, attributes]
# Index: []

# %% [markdown]
# # Angola vs Gabon

# %%
pbs_plot('3R', 'GAgam', 'AOcol', 'arab')

# %%
locate_genes('3R',0.2, 'GAgam', 'AOcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:55: RuntimeWarning: invalid value encountered in greater
# Found 25 SNPs with PBS values above 0.2
#  Total genes found: 9
#        seqid      source  type     start       end score strand phase  \
# 119911    3R  VectorBase  gene    149476    153955     .      +     .
# 119939    3R  VectorBase  gene    172973    173928     .      +     .
# 119983    3R  VectorBase  gene    195983    210038     .      -     .
# 120029    3R  VectorBase  gene    228685    256328     .      +     .
# 120104    3R  VectorBase  gene    267764    271254     .      -     .
# 120126    3R  VectorBase  gene    272627    279864     .      -     .
# 133965    3R  VectorBase  gene  15929030  15973388     .      -     .
# 155330    3R  VectorBase  gene  52042711  52059885     .      +     .
# 155544    3R  VectorBase  gene  52418651  52422892     .      -     .
#
#                                   attributes
# 119911  ID=AGAP007737;biotype=protein_coding
# 119939  ID=AGAP007740;biotype=protein_coding
# 119983  ID=AGAP007744;biotype=protein_coding
# 120029  ID=AGAP007751;biotype=protein_coding
# 120104  ID=AGAP007753;biotype=protein_coding
# 120126  ID=AGAP007754;biotype=protein_coding
# 133965  ID=AGAP008712;biotype=protein_coding
# 155330  ID=AGAP010283;biotype=protein_coding
# 155544  ID=AGAP010294;biotype=protein_coding

# %% [markdown]
# ## Sandbox - First time

# %%
pop_select = metadata.population.isin({'BFgam', 'BFcol', 'AOcol'}).values
pop_subset=metadata[pop_select]

# %%
genotypes_phase2_call = callset_phase2['3L']["calldata/GT"]
genotypes_phase2_call
# Out:
# <zarr.core.Array '/3L/calldata/GT' (10640388, 1142, 2) int8 read-only>

# %%
pos = allel.SortedIndex(callset_phase2["3L"]["variants/POS"])
pos
# Out:
# <SortedIndex shape=(10640388,) dtype=int32>
# [9790, 9791, 9798, 9812, 9815, ..., 41956532, 41956537, 41956541, 41956551, 41956556]

# %%
genotypes_phase2 = allel.GenotypeDaskArray(genotypes_phase2_call)
genotypes_phase2
# Out:
# <GenotypeDaskArray shape=(10640388, 1142, 2) dtype=int8>

# %%
geno_p2_subset = genotypes_phase2.subset(sel1=pop_select)
geno_p2_subset
# Out:
# <GenotypeDaskArray shape=(10640388, 245, 2) dtype=int8>

# %%
grp = pop_subset.groupby("population")
grp_indices = grp.indices
ac_subpops = geno_p2_subset.count_alleles_subpops(grp_indices)

# %%
pbs = allel.pbs(ac_subpops['BFcol'], ac_subpops['BFgam'], ac_subpops['AOcol'], 1000)

# %%
x = allel.moving_statistic(pos, statistic=lambda v: v[0], size=1000)

# %%
len(x), len(pbs)
# Out:
# (10640, 10640)

# %%
fig, ax = plt.subplots(figsize=(14, 3))
sns.despine(ax=ax, offset=10)
ax.plot(x, pbs, marker='o', linestyle=' ', mfc='none', mec='k', markersize=2)
ax.set_xlabel('Genome position (bp)')
ax.set_xlim(0, pos.max())
ax.set_ylabel('PBS');

# %%
x[pbs >0.30]
# Out:
# array([11166928, 11208561, 11218930, 11241787, 11590959, 11643851,
#        33282415], dtype=int32)

# %%
plot_genes(genome, geneset_fn, '3L', 11218830, 11219950, label=True, label_rotation=45, height=0.5)

# %%
plot_genes(genome, geneset_fn, '3L', 33282400, 33282420, label=True, label_rotation=45, height=0.5)

# %% [markdown]
# Found these genes with PBS value above 0.30:
#    - Gene: AGAP010816, Protein TEP3 - SNP Position 11218930
#    - Gene: AGAP011791, Protein CLIPA1 - SNP Position 33282415

# %% [markdown]
# ------------------------

# %%
def geneset_remastered(chrom, pos):   
    genes = get_geneset_features(geneset_fn, chrom, pos-100, pos+100).eq('type', 'gene').records()
    return genes

# %%
geneset_remastered('3L', 11218930)
# Out:
# ('3L', 'VectorBase', 'gene', 11215246, 11220064, '.', '-', '.', {'ID': 'AGAP010816', 'biotype': 'protein_coding'})

# %%
def geneset_pbs(chrom, pop1, pop2, pop3):
    
    results = pbs(chrom, pop1, pop2, pop3)
    over30 = results[0][results[2] > 0.25]
    tbl=[]
    
    for i in range(len(over30)):

        a = (get_geneset_features(geneset_fn, chrom, over30[i]-insert, over30[i]+100).eq('type', 'gene').records())
        
    #table2 = etl.pushheader(tbl, ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes'])
    #, columns =['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']
    #bl = pd.DataFrame(lst) 
    return tbl

# %%
def plot_genes_remastered(chrom, pos):
    plot_genes(genome, geneset_fn, chrom, pos-100, pos+100, label=True, label_rotation=45, height=0.5)

# %%
plot_genes_remastered('3L', 11218930)

# %%
def plot_genes_remastered(chrom, pos):
    plot_genes(genome, geneset_fn, chrom, pos-100, pos+100, label=True, label_rotation=45, height=0.5)

# %%
def plot_genes_pbs(chrom, pop1, pop2, pop3):
    
    results = pbs(chrom, pop1, pop2, pop3)
    over30 = results[0][results[2] > 0.25]
    print (over30)
    for i in range(len(over30)):
        plt.figure()
        plot_genes_remastered(chrom, over30[i])

# %%
plot_genes_pbs('3R', 'BFgam', 'BFcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.
# [  111880   121212   272465 38146011 39472026 40258889 43668516 43687557
#  43691476 47942907 49112203 49721608]
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# -------------------------

# %%
import gffpandas.gffpandas as gffpd

# %%
def locate_genes

# %%
col_names = ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']
df = pd.read_csv('/home/jovyan/notebooks/data/Anopheles-gambiae-PEST_BASEFEATURES_AgamP4.2.sorted.gff3.gz', compression='gzip',
                         sep='\t', comment='#', low_memory=False,
                         header=None, names=col_names)

# %%
df.head()
# Out:
#   seqid      source    type   start       end score strand phase  \
# 0    2L  VectorBase  contig       1  49364325     .      .     .
# 1    2L  VectorBase    exon  157348    157623     .      -     .
# 2    2L  VectorBase    exon  157348    157623     .      -     .
# 3    2L  VectorBase    gene  157348    186936     .      -     .
# 4    2L  VectorBase    mRNA  157348    181305     .      -     .
#
#                                           attributes
# 0  ID=2L;molecule_type=dsDNA;translation_table=1;...
# 1          ID=AGAP004677-RB-E4A;Parent=AGAP004677-RA
# 2          ID=AGAP004677-RB-E4B;Parent=AGAP004677-RB
# 3               ID=AGAP004677;biotype=protein_coding
# 4  ID=AGAP004677-RA;Parent=AGAP004677;Dbxref=RefS...

# %%
results = pbs('3L', 'BFgam', 'BFcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/allel/stats/fst.py:622: RuntimeWarning: invalid value encountered in true_divide
#   fst = num_sum / den_sum

# %%
over30 = results[0][results[2] > 0.25]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
df[(df.seqid == '3R') & (df.type == 'gene') & (df['start'] <= over30[0]-100) & (df['end'] >= over30[0]+100)]
# Out:
#        seqid      source  type     start       end score strand phase  \
# 129578    3R  VectorBase  gene  10236132  10238059     .      -     .
#
#                                   attributes
# 129578  ID=AGAP008385;biotype=protein_coding

# %%
def locate_genes(chrom, pop1, pop2, pop3):    
    
    col_names = ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']
    df = pd.read_csv('/home/jovyan/notebooks/data/Anopheles-gambiae-PEST_BASEFEATURES_AgamP4.2.sorted.gff3.gz', compression='gzip',
                             sep='\t', comment='#', low_memory=False,
                             header=None, names=col_names)
    
    results = pbs(chrom, pop1, pop2, pop3)
    over30 = results[0][results[2] > 0.25]
    df2 = pd.DataFrame([])
    for i in range(len(over30)):
        a=(df[(df.seqid == '3R') & (df.type == 'gene') & (df['start'] <= over30[i]-100) & (df['end'] >= over30[i]+100)])
        
        df2 = df2.append(a)
    return df2

# %%
locate_genes('3R', 'BFgam', 'BFcol', 'arab')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in greater
#   if __name__ == '__main__':
#        seqid      source  type     start       end score strand phase  \
# 119891    3R  VectorBase  gene     82151    142545     .      +     .
# 119891    3R  VectorBase  gene     82151    142545     .      +     .
# 146803    3R  VectorBase  gene  38137217  38154470     .      +     .
# 148425    3R  VectorBase  gene  43667301  43668635     .      -     .
# 148473    3R  VectorBase  gene  43676455  43697706     .      -     .
# 148473    3R  VectorBase  gene  43676455  43697706     .      -     .
#
#                                   attributes
# 119891  ID=AGAP007736;biotype=protein_coding
# 119891  ID=AGAP007736;biotype=protein_coding
# 146803  ID=AGAP009670;biotype=protein_coding
# 148425  ID=AGAP009802;biotype=protein_coding
# 148473  ID=AGAP009805;biotype=protein_coding
# 148473  ID=AGAP009805;biotype=protein_coding
